# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from dataset import DUNEImageDataset
from apa_dataset import APAImageDataset
from splits import train_val_split

import sys, os
sys.path.insert(0, os.path.abspath(".."))  # adds ml-dune-model/ to path

# %% [markdown]
# ## Test DUNECVN dataset class

# %%
rootdir = "/nfs/data/1/rrazakami/work/data_cvn/data/dune/2023_trainings/latest/dunevd"

label_tokens = [ "numu", "nue", "nutau", "NC" ]  # adapt if different

ds = DUNEImageDataset(
    datadir=rootdir,
    class_names=label_tokens,
    view_index=2,        # e.g. Z plane
    use_cache=True
)

print("Dataset size:", len(ds))

# %%
idx = 2000000  # try a few different indices later
x, y = ds[idx]

print("Index:", idx)
print("Label (int):", y)
print("Label (name):", ds.idx_to_class[y] if hasattr(ds, "idx_to_class") else y)
print("Image shape:", x.shape)
print("Image dtype:", x.dtype)
print("Min / Max:", x.min().item(), x.max().item())

# %%
# Remove channel dim for plotting
img = x.squeeze(0).cpu().numpy()

plt.figure(figsize=(6, 6))
plt.imshow(img.T, interpolation="none", cmap="twilight")
plt.colorbar(label="Normalized ADC")
plt.title(f"Sample {idx} | class = {ds.idx_to_class[y]}")
plt.xlabel("Wire")
plt.ylabel("Time tick")
plt.tight_layout()
plt.show()

# %%
from warpconvnet.geometry.types.voxels import Voxels

xbatch = x.unsqueeze(0)        # shape -> (1,1,960,1500) ADD BATCH DIM
vox = Voxels.from_dense(xbatch)

# --- extract voxel data ---
coords = vox.batch_indexed_coordinates.cpu().numpy()        # (N, 3)
feats  = vox.batched_features.batched_tensor.cpu().numpy()  # (N, 1)

print("coords shape:", coords.shape)    # expect (N, 3)
print("feats shape:", feats.shape)      # expect (N, 1)

# drop batch index -> 2D image coords
y = coords[:, 1]
x = coords[:, 2]

# scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(
    x, y,
    c=feats[:, 0],
    s=4,
    cmap="viridis",
    linewidths=0,
)
plt.gca().invert_yaxis()   # matches image convention
plt.xlabel("x")
plt.ylabel("y")
plt.title("Replotted image from Voxels (2D)")
plt.colorbar(label="value")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test training/validation split

# %%
train_ds, val_ds, train_idx, val_idx = train_val_split(ds, val_fraction=0.2, seed=42, use_cache=True)

# %%
print(len(ds), len(train_ds) + len(val_ds))
print(len(train_ds), len(train_ds) / len(ds))
print(len(val_ds), len(val_ds) / len(ds))

# %%
num_classes = len(ds.class_names)

full_counts  = torch.bincount(ds.labels, minlength=num_classes)
train_counts = torch.bincount(ds.labels[train_idx], minlength=num_classes)
val_counts   = torch.bincount(ds.labels[val_idx], minlength=num_classes)

# %%
print("Full:", full_counts, full_counts.float() / full_counts.sum())
print("Train:", train_counts, train_counts.float() / train_counts.sum())
print("Val:", val_counts, val_counts.float() / val_counts.sum())

# %% [markdown]
# ## Test APA custom dataset class

# %%
rootdir = "/nfs/data/1/mvicenzi/apa-test-data/gzip2"

ds = APAImageDataset(
    datadir=rootdir,
    apa=0,
    view="W",        # "U", "V", or "W"
    use_cache=True,
    cache_dir="../data",
)

print("Dataset size:", len(ds))

# %%
idx = 100  # try a few different indices
x = ds[idx]

print("Index:", idx)
print("Image shape:", x.shape)
print("Image dtype:", x.dtype)
print("Min / Max:", x.min().item(), x.max().item())

# %%
# Remove channel dim for plotting
img = x.squeeze(0).cpu().numpy()  # (ticks, wires)

plt.figure(figsize=(8, 5))
plt.imshow(
    img.T, # makes it (wires, ticks)
    interpolation="none",
    #aspect="auto",
    cmap="twilight",
)
plt.colorbar(label="ADC")
plt.title(f"APA {ds.apa} | View {ds.view} | Sample {idx}")
plt.xlabel("Wire")
plt.ylabel("Time tick")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)

for ax, view in zip(axes, ["U", "V", "W"]):
    ds_view = APAImageDataset(rootdir, apa=0, view=view, use_cache=True)
    img = ds_view[idx].squeeze(0).cpu().numpy()

    im = ax.imshow(img.T, cmap="twilight")
    ax.set_title(f"View {view}")
    ax.set_xlabel("Wire")

axes[0].set_ylabel("Time tick")
#fig.colorbar(im, ax=axes, label="ADC")
plt.tight_layout()
plt.show()

# %%
from warpconvnet.geometry.types.voxels import Voxels

idx = 100  # try a few different indices
x = ds[idx]

print("Index:", idx)
print("Image shape:", x.shape)
print("Image dtype:", x.dtype)
print("Min / Max:", x.min().item(), x.max().item())

dense = x.unsqueeze(0)        # shape -> (1,1,960,1500)
vox = Voxels.from_dense(dense)

print("\nVoxels object")
print("Type:", type(vox))

# quick introspection: try to print some attributes if available
for attr in ("batched_coordinates", "batched_features", "offsets"):
     if hasattr(vox, attr):
        v = getattr(vox, attr)
        try:
            print(f"{attr}: type={type(v)}, shape={v.shape}, dtype={v.dtype}")
        except Exception:
            print(f"{attr}: {v}")

# %%
# extract coords + values
coords = vox.batch_indexed_coordinates.cpu().numpy()   # (N, 3)
vals   = vox.batched_features.batched_tensor.cpu().numpy()[:, 0]  # (N,)

# drop batch index -> 2D image coords
y = coords[:, 1]
x = coords[:, 2]

# scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(
    x, y,
    c=vals,
    s=4,
    cmap="viridis",
    linewidths=0,
)
plt.gca().invert_yaxis()   # matches image convention
plt.xlabel("x")
plt.ylabel("y")
plt.title("Replotted image from Voxels (2D)")
plt.colorbar(label="value")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test APASparseDataset

# %%
from apa_sparse_dataset import APASparseDataset
from collate import voxels_collate_fn

rootdir_sparse = "/nfs/data/1/yuhw/cffm-data/prod-jay-100k-truth-2026-02-27"

ds_sparse = APASparseDataset(
    datadir=rootdir_sparse,
    apa=0,
    view="W",
    use_cache=True,
    cache_dir="../data",
)

print("Dataset size:", len(ds_sparse))

# %%
idx = 0
vox = ds_sparse[idx]

print("Index:", idx)
print("Batch size:", vox.batch_size)
print("Num active voxels:", vox.coordinate_tensor.shape[0])
print("Num channels:", vox.num_channels)
print("coordinate_tensor:", vox.coordinate_tensor.shape, vox.coordinate_tensor.dtype)
print("feature_tensor:   ", vox.feature_tensor.shape,    vox.feature_tensor.dtype)
print("offsets:          ", vox.offsets)

# %%
# Scatter plot of a single sparse sample
coords_np = vox.coordinate_tensor.cpu().numpy()
vals_np   = vox.feature_tensor.cpu().numpy()[:, 0]

ch_range = ds_sparse.ch_end - ds_sparse.ch_start
print("Channel range:", ch_range)

plt.figure(figsize=(8, 5))
plt.scatter(coords_np[:, 0], coords_np[:, 1], c=vals_np, s=1, cmap="viridis", linewidths=0)
plt.xlim(0, ch_range)
plt.ylim(0, 1500)
plt.xlabel("Wire (rebased)")
plt.ylabel("Time tick")
plt.title(f"APASparseDataset | APA {ds_sparse.apa} | View {ds_sparse.view} | Sample {idx}")
plt.colorbar(label="ADC")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DataLoader with voxels_collate_fn

# %%
from torch.utils.data import DataLoader

loader = DataLoader(
    ds_sparse,
    batch_size=4,
    shuffle=False,
    num_workers=0,
    collate_fn=voxels_collate_fn,
)

batch = next(iter(loader))

print("Batch type:", type(batch))
print("Batch size:", batch.batch_size)
print("Num active voxels (all items):", batch.coordinate_tensor.shape[0])
print("coordinate_tensor:", batch.coordinate_tensor.shape, batch.coordinate_tensor.dtype)
print("feature_tensor:   ", batch.feature_tensor.shape,    batch.feature_tensor.dtype)
print("offsets:          ", batch.offsets)

# sanity check: each offset difference equals the number of active voxels per sample
counts = batch.offsets[1:] - batch.offsets[:-1]
print("Active voxels per sample:", counts.tolist())

# %%
# Scatter plot of batched items, coloured by batch index
bic      = batch.batch_indexed_coordinates.cpu().numpy()  # (N_total, 3): (batch_idx, ch, tick)
vals_all = batch.feature_tensor.cpu().numpy()[:, 0]

ch_range = ds_sparse.ch_end - ds_sparse.ch_start

fig, axes = plt.subplots(1, batch.batch_size, figsize=(4 * batch.batch_size, 4), sharey=True)

for b, ax in enumerate(axes):
    mask = bic[:, 0] == b
    ax.scatter(bic[mask, 1], bic[mask, 2], c=vals_all[mask], s=1, cmap="viridis", linewidths=0)
    ax.set_xlim(0, ch_range)
    ax.set_ylim(0, 1500)
    ax.set_title(f"Batch item {b}")
    ax.set_xlabel("Wire (rebased)")

axes[0].set_ylabel("Time tick")
plt.suptitle(f"APASparseDataset batch | View {ds_sparse.view}", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Test APA SparseMetaDataset

# %%
from loader.apa_sparse_meta_dataset import APASparseMetaDataset

rootdir = "/nfs/data/1/yuhw/cffm-data/prod-jay-100k-truth-2026-02-27"

ds = APASparseMetaDataset(
    datadir=rootdir,
    apa=0,
    view="W",  
    use_cache=True,
    cache_dir="/nfs/data/1/mvicenzi/ml-dune-model/data",
    )

print("Dataset size:", len(ds))

# %%
train_ds, val_ds, train_idx, val_idx = train_val_split(ds, val_fraction=0.2, use_cache=False)

print(len(ds), len(train_ds) + len(val_ds))
print(len(train_ds), len(train_ds) / len(ds))
print(len(val_ds), len(val_ds) / len(ds))

# %%
from loader.apa_sparse_meta_dataset import CLASS_NAMES

num_classes = len(CLASS_NAMES)

# Build a flat labels tensor from the dataset
labels = torch.tensor([ds[i][1]["label"] for i in range(len(ds))], dtype=torch.long)

mask = labels >= 0
full_counts  = torch.bincount(labels[mask], minlength=num_classes)
train_counts = torch.bincount(labels[train_idx][labels[train_idx] >= 0], minlength=num_classes)
val_counts   = torch.bincount(labels[val_idx][labels[val_idx] >= 0], minlength=num_classes)

# %%
print("Full:", full_counts, full_counts.float() / full_counts.sum())
print("Train:", train_counts, train_counts.float() / train_counts.sum())
print("Val:", val_counts, val_counts.float() / val_counts.sum())
