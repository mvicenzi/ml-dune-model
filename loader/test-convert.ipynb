# %%
import h5py
import torch
from pathlib import Path
from warpconvnet.geometry.types.voxels import Voxels
import numpy as np

FRAME_RECO = "frame_rebinned_reco"
FRAME_TRK1 = "frame_trackid_1st"
FRAME_PID1 = "frame_pid_1st"
FRAME_TRK2 = "frame_trackid_2nd"
FRAME_PID2 = "frame_pid_2nd"
VIEW_RANGES = {
    "U": (0, 800),
    "V": (800, 1600),
    "W": (1600, 2650),
}
# Out:
# CuPy allocator set to PyTorch memory pool.

# %%
inpath = "../../apa-test-data/gzip2/out_monte-carlo-011984-000100_279569_164_1_20260116T164131Z/" \
        "monte-carlo-011984-000100_279569_164_1_20260116T164131Z_g4-tru-anode0.h5"
outpath = "../../apa-test-data/pickle/out_monte-carlo-011984-000100_279569_164_1_20260116T164131Z/" \
        "monte-carlo-011984-000100_279569_164_1_20260116T164131Z_g4-tru-anode0_sparse.pt"

# %%
def debug_print_voxels(vox, prefix="", full=False):
    print(f"{prefix}Voxels summary")
    print("Type:", type(vox))
    print("Batch size:", vox.batch_size)
    print("Num spatial dims:", vox.num_spatial_dims)
    print("Num channels:", vox.num_channels)
    print("Num active voxels:", vox.coordinate_tensor.shape[0])

    # --- core tensors ---
    print("Core tensors:")
    print("  coordinate_tensor:",
          vox.coordinate_tensor.shape,
          vox.coordinate_tensor.dtype,
          vox.coordinate_tensor.device)

    print("  feature_tensor:",
          vox.feature_tensor.shape,
          vox.feature_tensor.dtype,
          vox.feature_tensor.device)

    print("  offsets:",
          vox.offsets.shape,
          vox.offsets.dtype,
          vox.offsets.device)

    if full:
      # --- batch indexed coords ---
      bic = vox.batch_indexed_coordinates
      print("Batch-indexed coordinates:")
      print("  batch_indexed_coordinates:",
            bic.shape,
            bic.dtype)

      # --- extras / metadata ---
      print("\nExtras:")
      extras = vox.extra_attributes
      if not extras:
            print("  (none)")
      else:
            for k, v in extras.items():
                  if torch.is_tensor(v):
                        print(f"  {k}: tensor shape={v.shape}, dtype={v.dtype}")
                  else:
                        print(f"  {k}: {v}")

      # --- derived properties ---
      print("\nDerived properties:")
      print("  tensor_stride:", vox.tensor_stride)
      print("  voxel_size:", vox.voxel_size)
      print("  ordering:", vox.ordering)

# %%
ch_start, ch_end = VIEW_RANGES["W"]
h5_path = Path(inpath)

sparse_groups = {}

with h5py.File(h5_path, "r") as f:
    for group in f.keys():
   
        print(f"group: {group}")

        frame = f[group][FRAME_RECO][()]  # (channels, ticks)
        framepid1 = f[group][FRAME_PID1][()]  # (channels, ticks)
        frametrk1 = f[group][FRAME_TRK1][()]  # (channels, ticks
        framepid2 = f[group][FRAME_PID2][()]  # (channels, ticks)
        frametrk2 = f[group][FRAME_TRK2][()]  # (channels, ticks

        mask_ref = frame != 0
        mask_pid1 = framepid1 != 0
        mask_pid2 = framepid2 != 0
        mask_trk1 = frametrk1 != 0
        mask_trk2 = frametrk2 != 0

        print("=== Mask statistics ===")
        print(f"Active reco       : {mask_ref.sum()}")
        print(f"Active pid1       : {mask_pid1.sum()}")
        print(f"Active pid2       : {mask_pid2.sum()}")
        print(f"Active trk1       : {mask_trk1.sum()}")
        print(f"Active trk2       : {mask_trk2.sum()}")

        #assert np.array_equal(mask_pid1, mask_pid2)
        #assert np.array_equal(mask_pid1, mask_trk1)
        #assert np.array_equal(mask_pid1, mask_trk2)

        x = torch.from_numpy(frame).float()
        x = x.unsqueeze(0).unsqueeze(0)  # (B=1, C=1, H, W)

        vox = Voxels.from_dense(x)

        if group == "1":
            debug_print_voxels(vox, prefix=f"[{group}] ")

        # explicitly print offsets values:
        # offsets are 0, len(active_pixels) because batch size is 1
        print(vox.offsets.cpu())


        sparse_groups[group] = {
            "coords": vox.coordinate_tensor.cpu(),
            "features": vox.feature_tensor.cpu(),
            "offsets": vox.offsets.cpu()
        }

# create output directory if it doesn't exist
out_dir = Path(outpath).parent
out_dir.mkdir(parents=True, exist_ok=True)
torch.save(sparse_groups, outpath, pickle_protocol=5)

print(f"Saved sparse file: {outpath}")
# Out:
# group: 1
# === Mask statistics ===
# Active reco       : 7480
# Active pid1       : 4077
# Active pid2       : 25
# Active trk1       : 4077
# Active trk2       : 1210
# [1] Voxels summary
# Type: <class 'warpconvnet.geometry.types.voxels.Voxels'>
# Batch size: 1
# Num spatial dims: 2
# Num channels: 1
# Num active voxels: 7480
# Core tensors:
#   coordinate_tensor: torch.Size([7480, 2]) torch.int32 cpu
#   feature_tensor: torch.Size([7480, 1]) torch.float32 cpu
#   offsets: torch.Size([2]) torch.int64 cpu
# tensor([   0, 7480])
# group: 10
# === Mask statistics ===
# Active reco       : 8432
# Active pid1       : 3421
# Active pid2       : 61
# Active trk1       : 3421
# Active trk2       : 1031
# tensor([   0, 8432])
# group: 2
# === Mask statistics ===
# Active reco       : 13601
# Active pid1       : 6681
# Active pid2       : 168
# Active trk1       : 6681
# Active trk2       : 1636
# tensor([    0, 13601])
# group: 3
# === Mask statistics ===
# Active reco       : 3987
# Active pid1       : 1848
# Active pid2       : 92
# Active trk1       : 1848
# Active trk2       : 598
# tensor([   0, 3987])
# group: 4
# === Mask statistics ===
# Active reco       : 4546
# Active pid1       : 2768
# Active pid2       : 521
# Active trk1       : 2768
# Active trk2       : 699
# tensor([   0, 4546])
# group: 5
# === Mask statistics ===
# Active reco       : 4388
# Active pid1       : 2531
# Active pid2       : 28
# Active trk1       : 2531
# Active trk2       : 917
# tensor([   0, 4388])
# group: 6
# === Mask statistics ===
# Active reco       : 9898
# Active pid1       : 5249
# Active pid2       : 58
# Active trk1       : 5249
# Active trk2       : 1287
# tensor([   0, 9898])
# group: 7
# === Mask statistics ===
# Active reco       : 12521
# Active pid1       : 5620
# Active pid2       : 361
# Active trk1       : 5620
# Active trk2       : 926
# tensor([    0, 12521])
# group: 8
# === Mask statistics ===
# Active reco       : 7136
# Active pid1       : 4239
# Active pid2       : 48
# Active trk1       : 4239
# Active trk2       : 1775
# tensor([   0, 7136])
# group: 9
# === Mask statistics ===
# Active reco       : 1112
# Active pid1       : 436
# Active pid2       : 14
# Active trk1       : 436
# Active trk2       : 27
# tensor([   0, 1112])
# Saved sparse file: ../../apa-test-data/pickle/out_monte-carlo-011984-000100_279569_164_1_20260116T164131Z/monte-carlo-011984-000100_279569_164_1_20260116T164131Z_g4-tru-anode0_sparse.pt

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# --- build masks ---
mask_ref   = frame   != 0
mask_other = framepid1 != 0

only_ref   = mask_ref & ~mask_other
only_other = mask_other & ~mask_ref
both       = mask_ref & mask_other

# --- quantitative summary ---
print("=== Mask statistics ===")
print(f"Active ref        : {mask_ref.sum()}")
print(f"Active other      : {mask_other.sum()}")
print(f"Overlap (both)    : {both.sum()}")
print(f"Only ref          : {only_ref.sum()}")
print(f"Only other        : {only_other.sum()}")

# --- combined difference image ---
diff = np.zeros(mask_ref.shape, dtype=np.uint8)
diff[only_ref]   = 1   # red
diff[only_other] = 2   # blue
diff[both]       = 3   # green

# --- scatter plot version of the combined difference ---

plt.figure(figsize=(10, 5), dpi=200)

# ref only → red
y_ref, x_ref = np.where(only_ref)
plt.scatter(y_ref, x_ref,s=4,c="red",label="reco only")

# other only → blue
y_other, x_other = np.where(only_other)
plt.scatter(y_other, x_other,s=4,c="blue",label="pid only")

# both → black
y_both, x_both = np.where(both)
plt.scatter(y_both, x_both,s=4,c="black",label="both")

plt.xlabel("Wire")
plt.ylabel("Time tick")
plt.title("Spatial support comparison\nred=reco only, blue=pid only, black=both")
plt.gca().invert_yaxis()  # match imshow(origin="upper")
plt.legend(markerscale=3, frameon=False)
plt.tight_layout()
plt.show()



# --- side-by-side masks + XOR ---
fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True)

axes[0].imshow(mask_ref.T, cmap="gray", vmin=0, vmax=1, origin="upper")
axes[0].set_title("mask_ref")

axes[1].imshow(mask_other.T, cmap="gray", vmin=0, vmax=1, origin="upper")
axes[1].set_title("mask_other")

axes[2].imshow((mask_ref ^ mask_other).T, cmap="hot", vmin=0, vmax=1, origin="upper")
axes[2].set_title("XOR (differences)")

for ax in axes:
    ax.set_xlabel("Wire")
axes[0].set_ylabel("Time tick")

plt.tight_layout()
plt.show()

# --- value distributions in non-overlapping regions ---
plt.figure(figsize=(6, 5))
plt.hist(frame[only_ref].ravel(), bins=100, alpha=0.6, label="ref only")
plt.hist(framepid1[only_other].ravel(), bins=100, alpha=0.6, label="other only")
plt.xlabel("Pixel value")
plt.ylabel("Count")
plt.legend()
plt.title("Pixel values where supports differ")
plt.tight_layout()
plt.show()
# Out:
# === Mask statistics ===
# Active ref        : 1112
# Active other      : 436
# Overlap (both)    : 436
# Only ref          : 676
# Only other        : 0

# %%
from warpconvnet.geometry.types.voxels import Voxels
from warpconvnet.geometry.coords.integer import IntCoords
from warpconvnet.geometry.features.cat import CatFeatures

from warpconvnet.geometry.types.voxels import Voxels
from warpconvnet.geometry.coords.integer import IntCoords
from warpconvnet.geometry.features.cat import CatFeatures

sparse_groups = torch.load(outpath, map_location="cpu",weights_only=False)
voxels_per_group = {}

for group, data in sparse_groups.items():
    coords   = data["coords"]
    feats    = data["features"]
    offsets  = data["offsets"]

    coords_b = IntCoords(coords, offsets=offsets)
    feats_b  = CatFeatures(feats, offsets=offsets)

    vox = Voxels(
        batched_coordinates=coords_b,
        batched_features=feats_b,
        offsets=offsets
    )

    voxels_per_group[group] = vox

    if group == "1":
        debug_print_voxels(vox, prefix=f"[reconstructed {group}] ")
# Out:
# [reconstructed 1] Voxels summary
# Type: <class 'warpconvnet.geometry.types.voxels.Voxels'>
# Batch size: 1
# Num spatial dims: 2
# Num channels: 1
# Num active voxels: 7480
# Core tensors:
#   coordinate_tensor: torch.Size([7480, 2]) torch.int32 cpu
#   feature_tensor: torch.Size([7480, 1]) torch.float32 cpu
#   offsets: torch.Size([2]) torch.int64 cpu

# %%
def split_view_sparse(vox: Voxels, view: str) -> Voxels:
    lo, hi = VIEW_RANGES[view]
    mask = (vox.coordinate_tensor[:,0] >= lo) & (vox.coordinate_tensor[:,0] < hi)
    coords = vox.coordinate_tensor[mask].clone()
    feats  = vox.feature_tensor[mask]
    coords[:,0] -= lo  # rebase channel coordinates to 0 for this view
    offsets = torch.tensor([0, coords.shape[0]], dtype=torch.int64)
    return Voxels(IntCoords(coords, offsets), CatFeatures(feats, offsets), offsets)

# %%
import matplotlib.pyplot as plt

# --- open HDF5 ---
h5_path = Path(inpath)
with h5py.File(h5_path, "r") as f:

    group = "1"
    print(f"Group: {group}, frame: {FRAME_RECO}")

    # original dense image
    frame = f[group][FRAME_RECO][()]  # shape (channels, ticks)
    framepid = f[group][FRAME_PID1][()]  # shape (channels, ticks)

    for i in range(frame.shape[0]):
        for j in range(frame.shape[1]):
            if (frame[i, j] != 0):
                print(f"  Channel {i}, tick {j}: {frame[i, j]}, {framepid[i, j]}.")

    # reconstructed sparse
    sparse_groups = torch.load(outpath, map_location="cpu",weights_only=False)
    data = sparse_groups[group]
    coords   = data["coords"]
    feats    = data["features"]
    offsets  = data["offsets"]

    vox = Voxels(
        batched_coordinates=IntCoords(coords, offsets=offsets),
        batched_features=CatFeatures(feats, offsets=offsets),
        offsets=offsets
    )

    # --- plot all views ---
    fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)

    ### DIRECT DENSE PLOTTING
    for ax, view in zip(axes, ["U", "V", "W"]):
        lo, hi = VIEW_RANGES[view]
        img_dense = frame[lo:hi, :]        
        ax.imshow(img_dense.T, cmap="twilight", origin="lower")
        ax.set_title(f"Dense {view}")
        ax.set_xlabel("Wire")

    axes[0].set_ylabel("Time tick")
    plt.tight_layout()
    plt.show()

    ### SPARSE PLOTTING ALL VIEWS TOGETHER (TENSORS AS SAVED)
    fig, ax = plt.subplots(figsize=(15, 5))
        
    coords_np = vox.coordinate_tensor.cpu().numpy()
    vals_np   = vox.feature_tensor.cpu().numpy()[:, 0]
    y = coords_np[:, 1]
    x = coords_np[:, 0]

    ax.scatter(x, y, c=vals_np, s=4, cmap="viridis", linewidths=0)
    ax.axvline(x=800, color='red', linestyle='--')
    ax.axvline(x=1600, color='red', linestyle='--')
    ax.set_xlim(0, 2650)
    ax.set_ylim(0, 1500)
    #ax.invert_yaxis()
    ax.set_title(f"Sparse [ALL VIEWS]")
    ax.set_xlabel("Wire")
    ax.set_ylabel("Time tick")
    plt.tight_layout()
    plt.show()

    ### SPARSE PLOTTING SPLIT VIEWS
    fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)
    for ax, view in zip(axes, ["U", "V", "W"]):
        vox_view = split_view_sparse(vox, view)

        # scatter plot from sparse coords
        coords_np = vox_view.coordinate_tensor.cpu().numpy()
        vals_np   = vox_view.feature_tensor.cpu().numpy()[:, 0]

        y = coords_np[:, 1]
        x = coords_np[:, 0]

        ax.scatter(x, y, c=vals_np, s=1, marker=".", cmap="viridis", linewidths=0)
        #ax.invert_yaxis()
        ax.set_title(f"Sparse {view}")
        ax.set_xlabel("Wire")
        ax.set_xlim(0, 800)
        if view == "W":
            ax.set_xlim(0, 1050)
        ax.set_ylim(0, 1500)
# Out:
# Group: 1, frame: frame_rebinned_reco
#   Channel 0, tick 692: 13.182830810546875, 0.0.
#   Channel 0, tick 693: 62.89567565917969, 0.0.
#   Channel 0, tick 694: 79.13739013671875, 0.0.
#   Channel 0, tick 695: 89.72454833984375, 0.0.
#   Channel 0, tick 696: 273.8655090332031, 0.0.
#   Channel 0, tick 697: 118.16043090820312, 0.0.
#   Channel 0, tick 699: 23.301116943359375, 0.0.
#   Channel 119, tick 720: 28.10504913330078, 0.0.
#   Channel 119, tick 721: 2.4817733764648438, 0.0.
#   Channel 119, tick 722: 131.77215576171875, 0.0.
#   Channel 119, tick 723: 85.6370620727539, 0.0.
#   Channel 119, tick 724: 5.082435607910156, 0.0.
#   Channel 120, tick 720: 51.10350036621094, 0.0.
#   Channel 120, tick 721: 92.60549926757812, 0.0.
#   Channel 120, tick 722: 292.65948486328125, 0.0.
#   Channel 120, tick 723: 188.82884216308594, 0.0.
#   Channel 120, tick 724: 4.619537353515625, 0.0.
#   Channel 121, tick 720: 186.0717315673828, 0.0.
#   Channel 121, tick 721: 1171.267578125, 2212.0.
#   Channel 121, tick 722: 3157.947998046875, 2212.0.
#   Channel 121, tick 723: 1785.4566650390625, 2212.0.
#   Channel 121, tick 724: 133.32244873046875, 0.0.
#   Channel 121, tick 726: 37.170955657958984, 0.0.
#   Channel 121, tick 727: 4.235685348510742, 0.0.
#   Channel 122, tick 717: 6.285861968994141, 0.0.
#   Channel 122, tick 718: 55.151100158691406, 0.0.
#   Channel 122, tick 719: 9.685096740722656, 0.0.
#   Channel 122, tick 720: 250.804931640625, 0.0.
#   Channel 122, tick 721: 2997.415283203125, 2212.0.
#   Channel 122, tick 722: 8603.8154296875, 2212.0.
#   Channel 122, tick 723: 5170.13525390625, 2212.0.
#   Channel 122, tick 724: 705.2457885742188, 0.0.
#   Channel 123, tick 717: 2.7275009155273438, 0.0.
#   Channel 123, tick 718: 3.8973007202148438, 0.0.
#   Channel 123, tick 719: 79.81055450439453, 0.0.
#   Channel 123, tick 720: 181.2678985595703, 0.0.
#   Channel 123, tick 721: 2378.41650390625, 2212.0.
#   Channel 123, tick 722: 6745.396484375, 2212.0.
#   Channel 123, tick 723: 4182.21923828125, 13.0.
#   Channel 123, tick 724: 519.6679077148438, 0.0.
#   Channel 123, tick 725: 25.917251586914062, 0.0.
#   Channel 123, tick 726: 127.58152770996094, 0.0.
#   Channel 123, tick 727: 32.38951110839844, 0.0.
#   Channel 124, tick 720: 135.234619140625, 0.0.
#   Channel 124, tick 721: 1309.1671142578125, 13.0.
#   Channel 124, tick 722: 3417.48193359375, 13.0.
#   Channel 124, tick 723: 2056.5556640625, 13.0.
#   Channel 124, tick 724: 144.74444580078125, 0.0.
#   Channel 124, tick 726: 125.1329345703125, 0.0.
#   Channel 124, tick 727: 35.00323486328125, 0.0.
#   Channel 125, tick 720: 173.74452209472656, 0.0.
#   Channel 125, tick 721: 1113.5408935546875, 13.0.
#   Channel 125, tick 722: 2975.217529296875, 13.0.
#   Channel 125, tick 723: 1674.146728515625, 13.0.
#   Channel 125, tick 724: 168.9559326171875, 0.0.
#   Channel 125, tick 726: 10.900978088378906, 0.0.
#   Channel 125, tick 727: 11.875267028808594, 0.0.
#   Channel 126, tick 720: 202.95745849609375, 0.0.
#   Channel 126, tick 721: 1249.514404296875, 13.0.
#   Channel 126, tick 722: 3015.15234375, 13.0.
#   Channel 126, tick 723: 1652.2119140625, 13.0.
#   Channel 126, tick 724: 231.2835235595703, 0.0.
#   Channel 126, tick 725: 5.135627746582031, 0.0.
#   Channel 127, tick 720: 88.85255432128906, 0.0.
#   Channel 127, tick 721: 1381.705322265625, 13.0.
#   Channel 127, tick 722: 2846.85791015625, 13.0.
#   Channel 127, tick 723: 1161.5068359375, 13.0.
#   Channel 127, tick 724: 24.74554443359375, 0.0.
#   Channel 128, tick 720: 97.31597900390625, 13.0.
#   Channel 128, tick 721: 1603.6300048828125, 13.0.
#   Channel 128, tick 722: 2817.263671875, 13.0.
#   Channel 128, tick 723: 1048.359375, 13.0.
#   Channel 128, tick 724: 24.9954833984375, 0.0.
#   Channel 129, tick 720: 249.1985321044922, 13.0.
#   Channel 129, tick 721: 1853.6337890625, 13.0.
#   Channel 129, tick 722: 2716.489990234375, 13.0.
#   Channel 129, tick 723: 879.7618408203125, 13.0.
#   Channel 129, tick 724: 17.16278076171875, 0.0.
#   Channel 130, tick 720: 313.37078857421875, 13.0.
#   Channel 130, tick 721: 1847.6522216796875, 13.0.
#   Channel 130, tick 722: 2440.360107421875, 13.0.
#   Channel 130, tick 723: 714.1221313476562, 13.0.
#   Channel 130, tick 724: 15.536347389221191, 0.0.
#   Channel 131, tick 720: 365.2423095703125, 13.0.
#   Channel 131, tick 721: 2037.471435546875, 13.0.
#   Channel 131, tick 722: 2411.2626953125, 13.0.
#   Channel 131, tick 723: 575.0816650390625, 13.0.
#   Channel 132, tick 720: 446.55548095703125, 13.0.
#   Channel 132, tick 721: 2217.310791015625, 13.0.
#   Channel 132, tick 722: 2164.9609375, 13.0.
#   Channel 132, tick 723: 259.16961669921875, 0.0.
#   Channel 133, tick 717: 11.633720397949219, 0.0.
#   Channel 133, tick 718: 182.10247802734375, 0.0.
#   Channel 133, tick 719: 184.66908264160156, 0.0.
#   Channel 133, tick 720: 733.0358276367188, 13.0.
#   Channel 133, tick 721: 2629.2529296875, 13.0.
#   Channel 133, tick 722: 2276.82470703125, 13.0.
#   Channel 133, tick 723: 352.4551696777344, 0.0.
#   Channel 134, tick 717: 10.856925964355469, 0.0.
#   Channel 134, tick 718: 100.58472442626953, 0.0.
#   Channel 134, tick 719: 67.09706115722656, 0.0.
#   Channel 134, tick 720: 877.7136840820312, 13.0.
#   Channel 134, tick 721: 2847.47265625, 13.0.
#   Channel 134, tick 722: 2194.447998046875, 13.0.
#   Channel 134, tick 723: 481.0450744628906, 0.0.
#   Channel 134, tick 724: 19.37664794921875, 0.0.
#   Channel 135, tick 717: 5.363494873046875, 0.0.
#   Channel 135, tick 718: 83.27224731445312, 0.0.
#   Channel 135, tick 719: 57.08970642089844, 0.0.
#   Channel 135, tick 720: 887.5708618164062, 13.0.
#   Channel 135, tick 721: 2739.53466796875, 13.0.
#   Channel 135, tick 722: 1732.970703125, 13.0.
#   Channel 135, tick 723: 347.6413269042969, 0.0.
#   Channel 135, tick 724: 29.888534545898438, 0.0.
#   Channel 136, tick 717: 4.190704345703125, 0.0.
#   Channel 136, tick 718: 132.2361297607422, 0.0.
#   Channel 136, tick 719: 6.3534626960754395, 0.0.
#   Channel 136, tick 720: 1227.5184326171875, 13.0.
#   Channel 136, tick 721: 3372.76806640625, 13.0.
#   Channel 136, tick 722: 1818.475341796875, 13.0.
#   Channel 136, tick 723: 432.1181945800781, 0.0.
#   Channel 136, tick 724: 25.86341094970703, 0.0.
#   Channel 137, tick 717: 4.33074951171875, 0.0.
#   Channel 137, tick 718: 48.65354537963867, 0.0.
#   Channel 137, tick 719: 60.190242767333984, 0.0.
#   Channel 137, tick 720: 1616.3553466796875, 13.0.
#   Channel 137, tick 721: 3621.994384765625, 13.0.
#   Channel 137, tick 722: 1694.1668701171875, 13.0.
#   Channel 137, tick 723: 226.58920288085938, 0.0.
#   Channel 137, tick 724: 24.718727111816406, 0.0.
#   Channel 138, tick 717: 5.796833038330078, 0.0.
#   Channel 138, tick 719: 109.91353607177734, 13.0.
#   Channel 138, tick 720: 1842.27490234375, 13.0.
#   Channel 138, tick 721: 3421.000244140625, 13.0.
#   Channel 138, tick 722: 1282.68994140625, 13.0.
#   Channel 138, tick 724: 4.77691650390625, 0.0.
#   Channel 139, tick 717: 3.408630132675171, 0.0.
#   Channel 139, tick 718: 83.45862579345703, 0.0.
#   Channel 139, tick 719: 455.90032958984375, 13.0.
#   Channel 139, tick 720: 2837.2939453125, 13.0.
#   Channel 139, tick 721: 4386.2314453125, 13.0.
#   Channel 139, tick 722: 1511.7977294921875, 13.0.
#   Channel 139, tick 723: 117.89535522460938, 0.0.
#   Channel 139, tick 724: 22.1422119140625, 0.0.
#   Channel 140, tick 717: 6.2311859130859375, 0.0.
#   Channel 140, tick 718: 39.12657165527344, 0.0.
#   Channel 140, tick 719: 685.9942626953125, 13.0.
#   Channel 140, tick 720: 4003.4775390625, 13.0.
#   Channel 140, tick 721: 5116.58056640625, 13.0.
#   Channel 140, tick 722: 1396.14892578125, 13.0.
#   Channel 140, tick 723: 109.00119018554688, 0.0.
#   Channel 140, tick 724: 12.644912719726562, 0.0.
#   Channel 141, tick 717: 7.96331787109375, 0.0.
#   Channel 141, tick 718: 59.3070068359375, 0.0.
#   Channel 141, tick 719: 1176.773193359375, 13.0.
#   Channel 141, tick 720: 4897.6552734375, 13.0.
#   Channel 141, tick 721: 4672.9931640625, 13.0.
#   Channel 141, tick 722: 836.404052734375, 13.0.
#   Channel 141, tick 723: 30.088424682617188, 13.0.
#   Channel 141, tick 724: 2.156646728515625, 13.0.
#   Channel 142, tick 718: 60.098358154296875, 0.0.
#   Channel 142, tick 719: 1645.3236083984375, 13.0.
#   Channel 142, tick 720: 5088.7509765625, 13.0.
#   Channel 142, tick 721: 3630.481201171875, 13.0.
#   Channel 142, tick 722: 358.5849609375, 0.0.
#   Channel 143, tick 718: 284.4252014160156, 13.0.
#   Channel 143, tick 719: 2802.321044921875, 13.0.
#   Channel 143, tick 720: 5499.298828125, 13.0.
#   Channel 143, tick 721: 3107.65087890625, 13.0.
#   Channel 143, tick 722: 342.7382507324219, 0.0.
#   Channel 143, tick 723: 0.587188720703125, 0.0.
#   Channel 144, tick 717: 23.154937744140625, 0.0.
#   Channel 144, tick 718: 1233.569091796875, 13.0.
#   Channel 144, tick 719: 4960.7333984375, 13.0.
#   Channel 144, tick 720: 6188.1279296875, 13.0.
#   Channel 144, tick 721: 2815.3154296875, 13.0.
#   Channel 144, tick 722: 399.8172607421875, 0.0.
#   Channel 144, tick 723: 35.430816650390625, 0.0.
#   Channel 144, tick 724: 5.09869384765625, 0.0.
#   Channel 145, tick 715: 21.757844924926758, 0.0.
#   Channel 145, tick 716: 79.39913940429688, 0.0.
#   Channel 145, tick 717: 393.6729736328125, 13.0.
#   Channel 145, tick 718: 2569.638916015625, 13.0.
#   Channel 145, tick 719: 6755.6630859375, 13.0.
#   Channel 145, tick 720: 6119.888671875, 13.0.
#   Channel 145, tick 721: 2573.30126953125, 13.0.
#   Channel 145, tick 722: 278.30023193359375, 0.0.
#   Channel 145, tick 724: 3.3975179195404053, 0.0.
#   Channel 146, tick 717: 120.03515625, 13.0.
#   Channel 146, tick 718: 2353.839599609375, 13.0.
#   Channel 146, tick 719: 5442.99853515625, 13.0.
#   Channel 146, tick 720: 4348.00634765625, 13.0.
#   Channel 146, tick 721: 1567.93310546875, 13.0.
#   Channel 146, tick 722: 89.90263366699219, 0.0.
#   Channel 147, tick 717: 330.99334716796875, 13.0.
#   Channel 147, tick 718: 2305.6455078125, 13.0.
#   Channel 147, tick 719: 3819.802490234375, 13.0.
#   Channel 147, tick 720: 3460.2998046875, 13.0.
#   Channel 147, tick 721: 1343.425537109375, 13.0.
#   Channel 147, tick 722: 151.11233520507812, 0.0.
#   Channel 148, tick 717: 488.0890808105469, 13.0.
#   Channel 148, tick 718: 2620.652099609375, 13.0.
#   Channel 148, tick 719: 2966.71435546875, 13.0.
#   Channel 148, tick 720: 2767.99853515625, 13.0.
#   Channel 148, tick 721: 931.3215942382812, 13.0.
#   Channel 148, tick 722: 21.539215087890625, 0.0.
#   Channel 149, tick 715: 15.631332397460938, 0.0.
#   Channel 149, tick 716: 20.820648193359375, 0.0.
#   Channel 149, tick 717: 1158.6939697265625, 13.0.
#   Channel 149, tick 718: 3232.715087890625, 13.0.
#   Channel 149, tick 719: 2914.3671875, 13.0.
#   Channel 149, tick 720: 2632.27978515625, 13.0.
#   Channel 149, tick 721: 868.5731201171875, 13.0.
#   Channel 149, tick 722: 42.530364990234375, 0.0.
#   Channel 150, tick 715: 109.8516845703125, 0.0.
#   Channel 150, tick 716: 338.8357849121094, 13.0.
#   Channel 150, tick 717: 1862.044921875, 13.0.
#   Channel 150, tick 718: 3292.9208984375, 13.0.
#   Channel 150, tick 719: 2915.69970703125, 13.0.
#   Channel 150, tick 720: 2805.8203125, 13.0.
#   Channel 150, tick 721: 880.2547607421875, 13.0.
#   Channel 150, tick 722: 98.94014739990234, 0.0.
#   Channel 151, tick 715: 69.38190460205078, 0.0.
#   Channel 151, tick 716: 739.1353759765625, 13.0.
#   Channel 151, tick 717: 3138.083251953125, 13.0.
#   Channel 151, tick 718: 3662.9609375, 13.0.
#   Channel 151, tick 719: 2898.65576171875, 13.0.
#   Channel 151, tick 720: 2669.41552734375, 13.0.
#   Channel 151, tick 721: 693.1832885742188, 13.0.
#   Channel 151, tick 722: 23.409526824951172, 0.0.
#   Channel 152, tick 715: 188.9107208251953, 0.0.
#   Channel 152, tick 716: 1777.8941650390625, 13.0.
#   Channel 152, tick 717: 5445.392578125, 13.0.
#   Channel 152, tick 718: 4331.45556640625, 13.0.
#   Channel 152, tick 719: 2847.52880859375, 13.0.
#   Channel 152, tick 720: 2416.396240234375, 13.0.
#   Channel 152, tick 721: 559.0423583984375, 13.0.
#   Channel 152, tick 722: 8.551273345947266, 0.0.
#   Channel 153, tick 712: 2.583740234375, 0.0.
#   Channel 153, tick 713: 38.339691162109375, 0.0.
#   Channel 153, tick 715: 100.82064056396484, 0.0.
#   Channel 153, tick 716: 2323.46044921875, 13.0.
#   Channel 153, tick 717: 6527.72216796875, 13.0.
#   Channel 153, tick 718: 4776.357421875, 13.0.
#   Channel 153, tick 719: 3123.115234375, 13.0.
#   Channel 153, tick 720: 2399.922119140625, 13.0.
#   Channel 153, tick 721: 604.1227416992188, 0.0.
#   Channel 153, tick 722: 15.462056159973145, 0.0.
#   Channel 154, tick 715: 119.55714416503906, 0.0.
#   Channel 154, tick 716: 2389.07275390625, 13.0.
#   Channel 154, tick 717: 6234.75390625, 13.0.
#   Channel 154, tick 718: 4939.86767578125, 13.0.
#   Channel 154, tick 719: 3569.748046875, 13.0.
#   Channel 154, tick 720: 2184.543212890625, 13.0.
#   Channel 154, tick 721: 286.9570007324219, 0.0.
#   Channel 154, tick 723: 161.153564453125, 0.0.
#   Channel 154, tick 724: 115.40355682373047, 0.0.
#   Channel 155, tick 715: 241.9076385498047, 13.0.
#   Channel 155, tick 716: 2335.005126953125, 13.0.
#   Channel 155, tick 717: 4204.32763671875, 13.0.
#   Channel 155, tick 718: 2904.0732421875, 13.0.
#   Channel 155, tick 719: 3400.581298828125, 13.0.
#   Channel 155, tick 720: 2248.88720703125, 13.0.
#   Channel 155, tick 721: 310.59808349609375, 0.0.
#   Channel 155, tick 722: 54.27854919433594, 0.0.
#   Channel 155, tick 723: 303.0701904296875, 0.0.
#   Channel 155, tick 724: 195.8115234375, 0.0.
#   Channel 156, tick 712: 2.7807388305664062, 0.0.
#   Channel 156, tick 713: 24.69727325439453, 0.0.
#   Channel 156, tick 715: 661.830322265625, 13.0.
#   Channel 156, tick 716: 2850.9228515625, 13.0.
#   Channel 156, tick 717: 2931.158203125, 13.0.
#   Channel 156, tick 718: 1417.180419921875, 13.0.
#   Channel 156, tick 719: 2802.98876953125, 13.0.
#   Channel 156, tick 720: 1989.298828125, 13.0.
#   Channel 156, tick 721: 380.6358642578125, 0.0.
#   Channel 156, tick 722: 16.20288848876953, 0.0.
#   Channel 156, tick 723: 38.56165313720703, 0.0.
#   Channel 156, tick 724: 103.28606414794922, 0.0.
#   Channel 157, tick 713: 50.550926208496094, 0.0.
#   Channel 157, tick 714: 352.21038818359375, 13.0.
#   Channel 157, tick 715: 2225.845947265625, 13.0.
#   Channel 157, tick 716: 3984.4990234375, 13.0.
#   Channel 157, tick 717: 2282.5732421875, 13.0.
#   Channel 157, tick 718: 1313.8631591796875, 13.0.
#   Channel 157, tick 719: 2923.568603515625, 13.0.
#   Channel 157, tick 720: 1603.02490234375, 13.0.
#   Channel 157, tick 721: 46.62759780883789, 0.0.
#   Channel 158, tick 713: 246.7205810546875, 13.0.
#   Channel 158, tick 714: 1326.10498046875, 13.0.
#   Channel 158, tick 715: 3654.658935546875, 13.0.
#   Channel 158, tick 716: 4166.955078125, 13.0.
#   Channel 158, tick 717: 1680.61767578125, 13.0.
#   Channel 158, tick 718: 1471.15234375, 13.0.
#   Channel 158, tick 719: 3320.806884765625, 13.0.
#   Channel 158, tick 720: 1796.68701171875, 13.0.
#   Channel 158, tick 721: 60.798309326171875, 0.0.
#   Channel 159, tick 712: 25.670360565185547, 13.0.
#   Channel 159, tick 713: 890.32275390625, 13.0.
#   Channel 159, tick 714: 2285.28955078125, 13.0.
#   Channel 159, tick 715: 2517.451171875, 13.0.
#   Channel 159, tick 716: 1557.5994873046875, 13.0.
#   Channel 159, tick 717: 571.9984130859375, 13.0.
#   Channel 159, tick 718: 1946.3900146484375, 13.0.
#   Channel 159, tick 719: 4012.58837890625, 13.0.
#   Channel 159, tick 720: 1845.76904296875, 13.0.
#   Channel 159, tick 721: 49.517494201660156, 0.0.
#   Channel 160, tick 710: 85.65467071533203, 0.0.
#   Channel 160, tick 711: 63.07880401611328, 0.0.
#   Channel 160, tick 712: 313.2948913574219, 13.0.
#   Channel 160, tick 713: 1796.8603515625, 13.0.
#   Channel 160, tick 714: 2653.54736328125, 13.0.
#   Channel 160, tick 715: 1530.7347412109375, 13.0.
#   Channel 160, tick 716: 654.453125, 13.0.
#   Channel 160, tick 717: 448.3765563964844, 13.0.
#   Channel 160, tick 718: 2423.89794921875, 13.0.
#   Channel 160, tick 719: 4254.39111328125, 13.0.
#   Channel 160, tick 720: 1606.093017578125, 13.0.
#   Channel 160, tick 721: 10.295394897460938, 0.0.
#   Channel 160, tick 722: 9.886764526367188, 0.0.
#   Channel 161, tick 710: 62.0362548828125, 0.0.
#   Channel 161, tick 711: 113.55642700195312, 0.0.
#   Channel 161, tick 712: 509.65802001953125, 13.0.
#   Channel 161, tick 713: 2568.253173828125, 13.0.
#   Channel 161, tick 714: 3249.63623046875, 13.0.
#   Channel 161, tick 715: 1379.7261962890625, 13.0.
#   Channel 161, tick 716: 527.160888671875, 13.0.
#   Channel 161, tick 717: 248.13076782226562, 13.0.
#   Channel 161, tick 718: 1733.2197265625, 13.0.
#   Channel 161, tick 719: 2955.0625, 13.0.
#   Channel 161, tick 720: 924.9605102539062, 13.0.
#   Channel 161, tick 721: 17.7513427734375, 0.0.
#   Channel 161, tick 722: 15.32330322265625, 0.0.
#   Channel 162, tick 710: 181.94041442871094, 0.0.
#   Channel 162, tick 711: 213.16537475585938, 0.0.
#   Channel 162, tick 712: 584.0459594726562, 13.0.
#   Channel 162, tick 713: 3426.444091796875, 13.0.
#   Channel 162, tick 714: 5576.2060546875, 13.0.
#   Channel 162, tick 715: 2836.61181640625, 13.0.
#   Channel 162, tick 716: 455.6659851074219, 13.0.
#   Channel 162, tick 717: 338.64288330078125, 13.0.
#   Channel 162, tick 718: 2152.62109375, 13.0.
#   Channel 162, tick 719: 2971.8564453125, 13.0.
#   Channel 162, tick 720: 1012.2767944335938, 13.0.
#   Channel 162, tick 721: 308.4939880371094, 0.0.
#   Channel 162, tick 722: 315.7744140625, 0.0.
#   Channel 162, tick 723: 249.87181091308594, 0.0.
#   Channel 162, tick 724: 123.43755340576172, 0.0.
#   Channel 163, tick 710: 49.279083251953125, 0.0.
#   Channel 163, tick 711: 57.05522155761719, 0.0.
#   Channel 163, tick 712: 331.2901306152344, 13.0.
#   Channel 163, tick 713: 2829.889892578125, 13.0.
#   Channel 163, tick 714: 6199.32958984375, 13.0.
#   Channel 163, tick 715: 4299.5, 13.0.
#   Channel 163, tick 716: 993.4349365234375, 13.0.
#   Channel 163, tick 717: 728.405517578125, 13.0.
#   Channel 163, tick 718: 3138.61865234375, 13.0.
#   Channel 163, tick 719: 3694.53857421875, 13.0.
#   Channel 163, tick 720: 1088.191162109375, 13.0.
#   Channel 163, tick 721: 163.65728759765625, 0.0.
#   Channel 163, tick 722: 79.2735595703125, 0.0.
#   Channel 163, tick 723: 24.334854125976562, 0.0.
#   Channel 163, tick 724: 77.5761489868164, 0.0.
#   Channel 164, tick 710: 7.937358856201172, 0.0.
#   Channel 164, tick 711: 162.822998046875, 0.0.
#   Channel 164, tick 712: 252.55337524414062, 0.0.
#   Channel 164, tick 713: 1383.5743408203125, 13.0.
#   Channel 164, tick 714: 3858.20654296875, 13.0.
#   Channel 164, tick 715: 3355.368408203125, 13.0.
#   Channel 164, tick 716: 744.3515014648438, 13.0.
#   Channel 164, tick 717: 568.206298828125, 13.0.
#   Channel 164, tick 718: 3117.657958984375, 13.0.
#   Channel 164, tick 719: 3307.05615234375, 13.0.
#   Channel 164, tick 720: 625.2969360351562, 0.0.
#   Channel 164, tick 721: 62.18455505371094, 0.0.
#   Channel 164, tick 722: 153.0773162841797, 0.0.
#   Channel 164, tick 723: 127.06056213378906, 0.0.
#   Channel 164, tick 724: 43.199615478515625, 0.0.
#   Channel 165, tick 710: 83.84474182128906, 0.0.
#   Channel 165, tick 711: 302.126220703125, 0.0.
#   Channel 165, tick 712: 109.82012176513672, 0.0.
#   Channel 165, tick 713: 222.33193969726562, 13.0.
#   Channel 165, tick 714: 1012.1874389648438, 13.0.
#   Channel 165, tick 715: 1136.6378173828125, 13.0.
#   Channel 165, tick 716: 184.7810516357422, 13.0.
#   Channel 165, tick 717: 417.39617919921875, 13.0.
#   Channel 165, tick 718: 2638.905029296875, 13.0.
#   Channel 165, tick 719: 2460.34912109375, 13.0.
#   Channel 165, tick 720: 241.0928497314453, 0.0.
#   Channel 165, tick 723: 77.7633285522461, 0.0.
#   Channel 165, tick 724: 58.24333190917969, 0.0.
#   Channel 166, tick 713: 7.094291687011719, 0.0.
#   Channel 166, tick 714: 215.19578552246094, 0.0.
#   Channel 166, tick 715: 185.1055450439453, 0.0.
#   Channel 166, tick 716: 77.68821716308594, 0.0.
#   Channel 166, tick 717: 782.7754516601562, 13.0.
#   Channel 166, tick 718: 2827.034912109375, 13.0.
#   Channel 166, tick 719: 2274.686767578125, 13.0.
#   Channel 166, tick 720: 234.547119140625, 0.0.
#   Channel 166, tick 721: 1.2115259170532227, 0.0.
#   Channel 166, tick 722: 0.22181391716003418, 0.0.
#   Channel 167, tick 714: 121.20121765136719, 0.0.
#   Channel 167, tick 715: 225.4671173095703, 0.0.
#   Channel 167, tick 716: 277.1394958496094, 0.0.
#   Channel 167, tick 717: 1133.3818359375, 13.0.
#   Channel 167, tick 718: 3191.3740234375, 13.0.
#   Channel 167, tick 719: 2174.479736328125, 13.0.
#   Channel 167, tick 720: 291.6311950683594, 0.0.
#   Channel 168, tick 715: 12.757392883300781, 0.0.
#   Channel 168, tick 716: 23.1033935546875, 0.0.
#   Channel 168, tick 717: 825.664306640625, 13.0.
#   Channel 168, tick 718: 3070.05029296875, 13.0.
#   Channel 168, tick 719: 1910.3427734375, 13.0.
#   Channel 168, tick 720: 374.34454345703125, 0.0.
#   Channel 169, tick 715: 0.465728759765625, 0.0.
#   Channel 169, tick 716: 13.478790283203125, 0.0.
#   Channel 169, tick 717: 971.8550415039062, 13.0.
#   Channel 169, tick 718: 2954.94482421875, 13.0.
#   Channel 169, tick 719: 1574.87939453125, 13.0.
#   Channel 169, tick 720: 195.48709106445312, 0.0.
#   Channel 169, tick 721: 73.63859558105469, 0.0.
#   Channel 169, tick 722: 17.552871704101562, 0.0.
#   Channel 170, tick 715: 4.814056396484375, 0.0.
#   Channel 170, tick 716: 205.27386474609375, 0.0.
#   Channel 170, tick 717: 1390.55517578125, 13.0.
#   Channel 170, tick 718: 3049.68994140625, 13.0.
#   Channel 170, tick 719: 1435.3388671875, 13.0.
#   Channel 170, tick 720: 195.7272186279297, 0.0.
#   Channel 170, tick 721: 321.2054138183594, 0.0.
#   Channel 170, tick 722: 50.70302963256836, 0.0.
#   Channel 171, tick 716: 228.62188720703125, 0.0.
#   Channel 171, tick 717: 1444.6741943359375, 13.0.
#   Channel 171, tick 718: 2907.1943359375, 13.0.
#   Channel 171, tick 719: 1136.158447265625, 13.0.
#   Channel 171, tick 721: 169.64755249023438, 0.0.
#   Channel 171, tick 722: 48.06782531738281, 0.0.
#   Channel 172, tick 716: 187.7151641845703, 13.0.
#   Channel 172, tick 717: 1674.8131103515625, 13.0.
#   Channel 172, tick 718: 2888.267578125, 13.0.
#   Channel 172, tick 719: 1011.0701293945312, 13.0.
#   Channel 172, tick 720: 9.337265014648438, 0.0.
#   Channel 172, tick 721: 118.22174072265625, 0.0.
#   Channel 172, tick 722: 24.726181030273438, 0.0.
#   Channel 173, tick 716: 353.657470703125, 13.0.
#   Channel 173, tick 717: 2105.045654296875, 13.0.
#   Channel 173, tick 718: 2939.285888671875, 13.0.
#   Channel 173, tick 719: 990.6925048828125, 13.0.
#   Channel 173, tick 720: 291.5669250488281, 0.0.
#   Channel 173, tick 721: 382.8144226074219, 0.0.
#   Channel 173, tick 722: 35.04933166503906, 0.0.
#   Channel 174, tick 715: 0.2869415283203125, 0.0.
#   Channel 174, tick 716: 283.92425537109375, 13.0.
#   Channel 174, tick 717: 2180.11474609375, 13.0.
#   Channel 174, tick 718: 2820.46337890625, 13.0.
#   Channel 174, tick 719: 787.0341186523438, 13.0.
#   Channel 174, tick 720: 376.85198974609375, 0.0.
#   Channel 174, tick 721: 494.58514404296875, 0.0.
#   Channel 174, tick 722: 55.450775146484375, 0.0.
#   Channel 175, tick 715: 2.6334686279296875, 0.0.
#   Channel 175, tick 716: 398.1868591308594, 13.0.
#   Channel 175, tick 717: 2261.610595703125, 13.0.
#   Channel 175, tick 718: 2883.72509765625, 13.0.
#   Channel 175, tick 719: 785.1632080078125, 13.0.
#   Channel 175, tick 720: 332.23284912109375, 0.0.
#   Channel 175, tick 721: 332.55615234375, 0.0.
#   Channel 175, tick 722: 41.758544921875, 0.0.
#   Channel 176, tick 715: 94.81405639648438, 0.0.
#   Channel 176, tick 716: 730.68310546875, 13.0.
#   Channel 176, tick 717: 2539.02587890625, 13.0.
#   Channel 176, tick 718: 2791.900390625, 13.0.
#   Channel 176, tick 719: 774.3853759765625, 0.0.
#   Channel 176, tick 720: 246.8355255126953, 0.0.
#   Channel 176, tick 721: 209.2615203857422, 0.0.
#   Channel 176, tick 722: 23.5919189453125, 0.0.
#   Channel 177, tick 715: 146.51092529296875, 0.0.
#   Channel 177, tick 716: 847.320068359375, 13.0.
#   Channel 177, tick 717: 2838.69287109375, 13.0.
#   Channel 177, tick 718: 2625.4560546875, 13.0.
#   Channel 177, tick 719: 511.13397216796875, 0.0.
#   Channel 177, tick 720: 51.63441467285156, 0.0.
#   Channel 177, tick 721: 0.6752395629882812, 0.0.
#   Channel 178, tick 715: 100.0677490234375, 13.0.
#   Channel 178, tick 716: 922.2077026367188, 13.0.
#   Channel 178, tick 717: 3272.110107421875, 13.0.
#   Channel 178, tick 718: 2545.3271484375, 13.0.
#   Channel 178, tick 719: 373.38531494140625, 0.0.
#   Channel 178, tick 720: 0.49250033497810364, 0.0.
#   Channel 179, tick 716: 719.920654296875, 13.0.
#   Channel 179, tick 717: 2996.82763671875, 13.0.
#   Channel 179, tick 718: 1978.220947265625, 13.0.
#   Channel 179, tick 719: 234.42401123046875, 0.0.
#   Channel 179, tick 721: 26.98175048828125, 0.0.
#   Channel 180, tick 716: 771.9522094726562, 13.0.
#   Channel 180, tick 717: 2817.887451171875, 13.0.
#   Channel 180, tick 718: 1508.3839111328125, 13.0.
#   Channel 180, tick 719: 105.75053405761719, 0.0.
#   Channel 180, tick 721: 21.78594207763672, 0.0.
#   Channel 181, tick 715: 106.80787658691406, 13.0.
#   Channel 181, tick 716: 1394.6258544921875, 13.0.
#   Channel 181, tick 717: 3112.7373046875, 13.0.
#   Channel 181, tick 718: 1418.009765625, 13.0.
#   Channel 181, tick 719: 20.85174560546875, 0.0.
#   Channel 181, tick 720: 16.387588500976562, 0.0.
#   Channel 181, tick 721: 127.286376953125, 0.0.
#   Channel 182, tick 715: 280.1366882324219, 13.0.
#   Channel 182, tick 716: 1790.8985595703125, 13.0.
#   Channel 182, tick 717: 3209.8896484375, 13.0.
#   Channel 182, tick 718: 1405.44873046875, 13.0.
#   Channel 182, tick 719: 8.18011474609375, 0.0.
#   Channel 182, tick 721: 13.598175048828125, 0.0.
#   Channel 183, tick 715: 228.9337158203125, 13.0.
#   Channel 183, tick 716: 1781.8775634765625, 13.0.
#   Channel 183, tick 717: 3123.721435546875, 13.0.
#   Channel 183, tick 718: 1331.0555419921875, 13.0.
#   Channel 183, tick 719: 155.01229858398438, 0.0.
#   Channel 183, tick 720: 8.775487899780273, 0.0.
#   Channel 183, tick 721: 25.604106903076172, 0.0.
#   Channel 184, tick 705: 13.403453826904297, 0.0.
#   Channel 184, tick 708: 43.879600524902344, 13.0.
#   Channel 184, tick 712: 1.4946727752685547, 0.0.
#   Channel 184, tick 713: 13.3485689163208, 0.0.
#   Channel 184, tick 714: 123.10179901123047, 0.0.
#   Channel 184, tick 715: 433.8276062011719, 13.0.
#   Channel 184, tick 716: 1847.8101806640625, 13.0.
#   Channel 184, tick 717: 2992.3173828125, 13.0.
#   Channel 184, tick 718: 1086.4964599609375, 13.0.
#   Channel 184, tick 719: 39.4566764831543, 0.0.
#   Channel 184, tick 722: 0.6732025146484375, 0.0.
#   Channel 185, tick 706: 192.22479248046875, 13.0.
#   Channel 185, tick 707: 1231.0426025390625, 13.0.
#   Channel 185, tick 708: 836.8282470703125, 13.0.
#   Channel 185, tick 709: 48.796875, 0.0.
#   Channel 185, tick 712: 20.576065063476562, 0.0.
#   Channel 185, tick 713: 154.41224670410156, 0.0.
#   Channel 185, tick 714: 5.0726318359375, 0.0.
#   Channel 185, tick 715: 292.93328857421875, 13.0.
#   Channel 185, tick 716: 1747.9139404296875, 13.0.
#   Channel 185, tick 717: 2673.94384765625, 13.0.
#   Channel 185, tick 718: 723.328857421875, 13.0.
#   Channel 185, tick 721: 24.56817626953125, 0.0.
#   Channel 185, tick 722: 22.23724365234375, 0.0.
#   Channel 186, tick 705: 62.49034118652344, 0.0.
#   Channel 186, tick 706: 1158.1287841796875, 13.0.
#   Channel 186, tick 707: 2979.9599609375, 13.0.
#   Channel 186, tick 708: 1603.753662109375, 13.0.
#   Channel 186, tick 709: 100.28565216064453, 0.0.
#   Channel 186, tick 710: 15.1292724609375, 0.0.
#   Channel 186, tick 711: 69.82540893554688, 0.0.
#   Channel 186, tick 712: 159.4741668701172, 0.0.
#   Channel 186, tick 713: 260.507080078125, 0.0.
#   Channel 186, tick 714: 37.91796875, 0.0.
#   Channel 186, tick 715: 149.94863891601562, 13.0.
#   Channel 186, tick 716: 1688.2879638671875, 13.0.
#   Channel 186, tick 717: 2199.157470703125, 13.0.
#   Channel 186, tick 718: 426.8296813964844, 13.0.
#   Channel 186, tick 721: 61.39961242675781, 0.0.
#   Channel 186, tick 722: 27.10045051574707, 0.0.
#   Channel 187, tick 702: 2.93035888671875, 0.0.
#   Channel 187, tick 705: 189.6638946533203, 13.0.
#   Channel 187, tick 706: 1684.5386962890625, 13.0.
#   Channel 187, tick 707: 2695.858154296875, 13.0.
#   Channel 187, tick 708: 1032.6656494140625, 13.0.
#   Channel 187, tick 715: 199.76748657226562, 13.0.
#   Channel 187, tick 716: 1938.398681640625, 13.0.
#   Channel 187, tick 717: 2299.9814453125, 13.0.
#   Channel 187, tick 718: 544.769287109375, 13.0.
#   Channel 187, tick 719: 7.106964111328125, 0.0.
#   Channel 187, tick 721: 32.1954345703125, 0.0.
#   Channel 187, tick 722: 15.80706787109375, 0.0.
#   Channel 188, tick 704: 37.01360321044922, 0.0.
#   Channel 188, tick 705: 578.4710693359375, 13.0.
#   Channel 188, tick 706: 2272.102783203125, 13.0.
#   Channel 188, tick 707: 2160.03662109375, 13.0.
#   Channel 188, tick 708: 477.05499267578125, 0.0.
#   Channel 188, tick 710: 1.158782958984375, 0.0.
#   Channel 188, tick 715: 360.0963134765625, 13.0.
#   Channel 188, tick 716: 2372.3779296875, 13.0.
#   Channel 188, tick 717: 2667.373779296875, 13.0.
#   Channel 188, tick 718: 653.3650512695312, 0.0.
#   Channel 188, tick 719: 85.00204467773438, 0.0.
#   Channel 188, tick 720: 55.97503662109375, 0.0.
#   Channel 188, tick 721: 150.32809448242188, 0.0.
#   Channel 188, tick 722: 12.964584350585938, 0.0.
#   Channel 189, tick 702: 10.529266357421875, 0.0.
#   Channel 189, tick 703: 252.1389923095703, 0.0.
#   Channel 189, tick 704: 549.3496704101562, 0.0.
#   Channel 189, tick 705: 1441.949951171875, 13.0.
#   Channel 189, tick 706: 3279.267822265625, 13.0.
#   Channel 189, tick 707: 2153.278076171875, 13.0.
#   Channel 189, tick 708: 400.4134216308594, 0.0.
#   Channel 189, tick 710: 151.84759521484375, 0.0.
#   Channel 189, tick 711: 293.66900634765625, 0.0.
#   Channel 189, tick 712: 402.9037780761719, 0.0.
#   Channel 189, tick 713: 194.84368896484375, 0.0.
#   Channel 189, tick 714: 15.110671997070312, 0.0.
#   Channel 189, tick 715: 560.1556396484375, 13.0.
#   Channel 189, tick 716: 2628.56005859375, 13.0.
#   Channel 189, tick 717: 2500.312744140625, 13.0.
#   Channel 189, tick 718: 528.4275512695312, 0.0.
#   Channel 189, tick 719: 30.92717742919922, 0.0.
#   Channel 190, tick 702: 12.158267974853516, 0.0.
#   Channel 190, tick 703: 202.84120178222656, 13.0.
#   Channel 190, tick 704: 781.2068481445312, 13.0.
#   Channel 190, tick 705: 2355.39501953125, 13.0.
#   Channel 190, tick 706: 4421.98681640625, 13.0.
#   Channel 190, tick 707: 2155.630615234375, 13.0.
#   Channel 190, tick 708: 183.39686584472656, 0.0.
#   Channel 190, tick 711: 3.431885004043579, 0.0.
#   Channel 190, tick 712: 73.73252868652344, 0.0.
#   Channel 190, tick 713: 114.4463882446289, 0.0.
#   Channel 190, tick 714: 22.03604507446289, 0.0.
#   Channel 190, tick 715: 627.3818359375, 13.0.
#   Channel 190, tick 716: 2702.882568359375, 13.0.
#   Channel 190, tick 717: 2256.592529296875, 13.0.
#   Channel 190, tick 718: 398.903564453125, 0.0.
#   Channel 190, tick 719: 29.15287971496582, 0.0.
#   Channel 191, tick 702: 23.245285034179688, 0.0.
#   Channel 191, tick 703: 623.5607299804688, 13.0.
#   Channel 191, tick 704: 2408.8095703125, 13.0.
#   Channel 191, tick 705: 4533.619140625, 13.0.
#   Channel 191, tick 706: 6201.9296875, 13.0.
#   Channel 191, tick 707: 3180.9970703125, 13.0.
#   Channel 191, tick 708: 712.1220703125, 0.0.
#   Channel 191, tick 709: 578.1123046875, 0.0.
#   Channel 191, tick 710: 584.1027221679688, 0.0.
#   Channel 191, tick 711: 462.10577392578125, 0.0.
#   Channel 191, tick 712: 419.0337829589844, 0.0.
#   Channel 191, tick 713: 539.7431030273438, 0.0.
#   Channel 191, tick 714: 346.8659362792969, 0.0.
#   Channel 191, tick 715: 1068.1328125, 13.0.
#   Channel 191, tick 716: 2930.249267578125, 13.0.
#   Channel 191, tick 717: 2126.2705078125, 13.0.
#   Channel 191, tick 718: 394.45062255859375, 0.0.
#   Channel 191, tick 719: 30.526351928710938, 0.0.
#   Channel 192, tick 703: 185.25390625, 13.0.
#   Channel 192, tick 704: 1424.8614501953125, 13.0.
#   Channel 192, tick 705: 2814.502685546875, 13.0.
#   Channel 192, tick 706: 3343.53564453125, 13.0.
#   Channel 192, tick 707: 1419.2861328125, 13.0.
#   Channel 192, tick 708: 113.88314819335938, 13.0.
#   Channel 192, tick 709: 186.76507568359375, 0.0.
#   Channel 192, tick 710: 286.0044250488281, 0.0.
#   Channel 192, tick 711: 295.9459228515625, 0.0.
#   Channel 192, tick 712: 34.906768798828125, 0.0.
#   Channel 192, tick 713: 8.797210693359375, 0.0.
#   Channel 192, tick 714: 109.72113037109375, 0.0.
#   Channel 192, tick 715: 959.8291015625, 13.0.
#   Channel 192, tick 716: 2853.315673828125, 13.0.
#   Channel 192, tick 717: 1826.884033203125, 13.0.
#   Channel 192, tick 718: 344.81256103515625, 0.0.
#   Channel 192, tick 719: 227.52352905273438, 0.0.
#   Channel 192, tick 720: 278.6258850097656, 0.0.
#   Channel 192, tick 721: 97.14605712890625, 0.0.
#   Channel 193, tick 703: 49.527626037597656, 13.0.
#   Channel 193, tick 704: 97.3732681274414, 0.0.
#   Channel 193, tick 705: 346.28106689453125, 13.0.
#   Channel 193, tick 706: 408.86517333984375, 13.0.
#   Channel 193, tick 707: 39.93074417114258, 13.0.
#   Channel 193, tick 708: 43.82618713378906, 13.0.
#   Channel 193, tick 709: 42.627681732177734, 0.0.
#   Channel 193, tick 711: 77.72683715820312, 0.0.
#   Channel 193, tick 712: 32.68802261352539, 0.0.
#   Channel 193, tick 714: 120.29132843017578, 0.0.
#   Channel 193, tick 715: 1257.4427490234375, 13.0.
#   Channel 193, tick 716: 3126.3115234375, 13.0.
#   Channel 193, tick 717: 1541.140869140625, 13.0.
#   Channel 193, tick 718: 43.56719207763672, 0.0.
#   Channel 193, tick 720: 8.096870422363281, 0.0.
#   Channel 194, tick 705: 32.863006591796875, 13.0.
#   Channel 194, tick 706: 215.20953369140625, 13.0.
#   Channel 194, tick 707: 71.81002807617188, 13.0.
#   Channel 194, tick 708: 314.6565246582031, 0.0.
#   Channel 194, tick 709: 173.97003173828125, 0.0.
#   Channel 194, tick 712: 3.965545892715454, 0.0.
#   Channel 194, tick 713: 5.126434326171875, 0.0.
#   Channel 194, tick 714: 124.2694091796875, 0.0.
#   Channel 194, tick 715: 1327.63134765625, 13.0.
#   Channel 194, tick 716: 2886.997314453125, 13.0.
#   Channel 194, tick 717: 1314.2508544921875, 13.0.
#   Channel 194, tick 718: 36.896240234375, 0.0.
#   Channel 194, tick 720: 5.0491943359375, 0.0.
#   Channel 194, tick 721: 86.75262451171875, 0.0.
#   Channel 194, tick 722: 26.730255126953125, 0.0.
#   Channel 195, tick 714: 99.29653930664062, 0.0.
#   Channel 195, tick 715: 1309.719482421875, 13.0.
#   Channel 195, tick 716: 2563.29052734375, 13.0.
#   Channel 195, tick 717: 1182.5001220703125, 13.0.
#   Channel 195, tick 718: 335.31365966796875, 0.0.
#   Channel 195, tick 719: 273.58428955078125, 0.0.
#   Channel 195, tick 720: 384.86566162109375, 0.0.
#   Channel 195, tick 721: 303.04656982421875, 0.0.
#   Channel 195, tick 722: 30.935302734375, 0.0.
#   Channel 196, tick 714: 142.46788024902344, 13.0.
#   Channel 196, tick 715: 1529.7098388671875, 13.0.
#   Channel 196, tick 716: 2556.206298828125, 13.0.
#   Channel 196, tick 717: 782.4295654296875, 13.0.
#   Channel 196, tick 718: 68.60838317871094, 0.0.
#   Channel 196, tick 720: 65.63926696777344, 0.0.
#   Channel 196, tick 721: 11.474830627441406, 0.0.
#   Channel 196, tick 722: 1.9073486328125e-06, 0.0.
#   Channel 197, tick 712: 7.714111328125, 0.0.
#   Channel 197, tick 713: 219.9890899658203, 0.0.
#   Channel 197, tick 714: 430.17919921875, 13.0.
#   Channel 197, tick 715: 1996.4969482421875, 13.0.
#   Channel 197, tick 716: 3024.041748046875, 13.0.
#   Channel 197, tick 717: 890.3809204101562, 13.0.
#   Channel 197, tick 718: 86.14019775390625, 0.0.
#   Channel 197, tick 719: 14.185516357421875, 0.0.
#   Channel 197, tick 720: 33.8160400390625, 0.0.
#   Channel 198, tick 712: 6.188804626464844, 0.0.
#   Channel 198, tick 714: 217.18621826171875, 13.0.
#   Channel 198, tick 715: 2270.64599609375, 13.0.
#   Channel 198, tick 716: 3045.406005859375, 13.0.
#   Channel 198, tick 717: 914.5012817382812, 13.0.
#   Channel 198, tick 718: 188.01123046875, 0.0.
#   Channel 198, tick 719: 36.95307159423828, 0.0.
#   Channel 198, tick 720: 39.624168395996094, 0.0.
#   Channel 199, tick 712: 1.5973604917526245, 0.0.
#   Channel 199, tick 714: 224.20301818847656, 13.0.
#   Channel 199, tick 715: 2535.36376953125, 13.0.
#   Channel 199, tick 716: 2954.037109375, 13.0.
#   Channel 199, tick 717: 673.6919555664062, 13.0.
#   Channel 199, tick 718: 36.20814895629883, 0.0.
#   Channel 200, tick 712: 7.663970947265625, 0.0.
#   Channel 200, tick 713: 52.563507080078125, 0.0.
#   Channel 200, tick 714: 410.909912109375, 13.0.
#   Channel 200, tick 715: 2670.11865234375, 13.0.
#   Channel 200, tick 716: 2601.75146484375, 13.0.
#   Channel 200, tick 717: 414.2169494628906, 0.0.
#   Channel 200, tick 718: 10.820037841796875, 0.0.
#   Channel 200, tick 720: 72.34369659423828, 0.0.
#   Channel 200, tick 721: 186.53854370117188, 0.0.
#   Channel 200, tick 722: 4.631805419921875, 0.0.
#   Channel 201, tick 714: 417.18328857421875, 13.0.
#   Channel 201, tick 715: 2644.5712890625, 13.0.
#   Channel 201, tick 716: 2313.04541015625, 13.0.
#   Channel 201, tick 717: 394.5167236328125, 0.0.
#   Channel 201, tick 718: 7.5150146484375, 0.0.
#   Channel 202, tick 712: 19.919654846191406, 0.0.
#   Channel 202, tick 713: 14.34063720703125, 0.0.
#   Channel 202, tick 714: 717.8978271484375, 13.0.
#   Channel 202, tick 715: 2912.91015625, 13.0.
#   Channel 202, tick 716: 2400.8623046875, 13.0.
#   Channel 202, tick 717: 462.95989990234375, 0.0.
#   Channel 202, tick 718: 13.2666015625, 0.0.
#   Channel 203, tick 712: 30.222686767578125, 0.0.
#   Channel 203, tick 713: 59.65570068359375, 0.0.
#   Channel 203, tick 714: 819.7952880859375, 13.0.
#   Channel 203, tick 715: 3448.08642578125, 13.0.
#   Channel 203, tick 716: 2375.846435546875, 13.0.
#   Channel 203, tick 717: 256.4811096191406, 0.0.
#   Channel 203, tick 718: 3.826690673828125, 0.0.
#   Channel 204, tick 714: 939.090576171875, 13.0.
#   Channel 204, tick 715: 3924.73291015625, 13.0.
#   Channel 204, tick 716: 2268.788818359375, 13.0.
#   Channel 204, tick 717: 139.05569458007812, 0.0.
#   Channel 205, tick 714: 1056.7667236328125, 13.0.
#   Channel 205, tick 715: 3545.9365234375, 13.0.
#   Channel 205, tick 716: 1806.2991943359375, 13.0.
#   Channel 205, tick 717: 125.93521118164062, 0.0.
#   Channel 205, tick 719: 11.107635498046875, 0.0.
#   Channel 206, tick 713: 66.55978393554688, 0.0.
#   Channel 206, tick 714: 1308.6202392578125, 13.0.
#   Channel 206, tick 715: 3228.22802734375, 13.0.
#   Channel 206, tick 716: 1659.4967041015625, 13.0.
#   Channel 206, tick 717: 398.84661865234375, 0.0.
#   Channel 206, tick 718: 221.30694580078125, 0.0.
#   Channel 206, tick 719: 57.141937255859375, 0.0.
#   Channel 207, tick 713: 223.0894012451172, 0.0.
#   Channel 207, tick 714: 1617.613525390625, 13.0.
#   Channel 207, tick 715: 3196.6416015625, 13.0.
#   Channel 207, tick 716: 1386.0872802734375, 13.0.
#   Channel 207, tick 717: 142.81747436523438, 0.0.
#   Channel 207, tick 718: 34.39122009277344, 0.0.
#   Channel 207, tick 719: 18.80889892578125, 0.0.
#   Channel 208, tick 713: 155.37298583984375, 13.0.
#   Channel 208, tick 714: 1647.9696044921875, 13.0.
#   Channel 208, tick 715: 3154.720703125, 13.0.
#   Channel 208, tick 716: 1139.8079833984375, 13.0.
#   Channel 208, tick 717: 187.36000061035156, 0.0.
#   Channel 209, tick 713: 165.45541381835938, 13.0.
#   Channel 209, tick 714: 1780.4727783203125, 13.0.
#   Channel 209, tick 715: 3066.0927734375, 13.0.
#   Channel 209, tick 716: 1128.4049072265625, 13.0.
#   Channel 209, tick 717: 187.06976318359375, 0.0.
#   Channel 209, tick 718: 51.832366943359375, 0.0.
#   Channel 210, tick 712: 2.569854736328125, 0.0.
#   Channel 210, tick 713: 429.8575134277344, 13.0.
#   Channel 210, tick 714: 2155.462158203125, 13.0.
#   Channel 210, tick 715: 2830.54541015625, 13.0.
#   Channel 210, tick 716: 837.9880981445312, 13.0.
#   Channel 210, tick 718: 3.147644281387329, 0.0.
#   Channel 211, tick 712: 2.0497665405273438, 0.0.
#   Channel 211, tick 713: 486.6214599609375, 13.0.
#   Channel 211, tick 714: 2606.887451171875, 13.0.
#   Channel 211, tick 715: 3164.513916015625, 13.0.
#   Channel 211, tick 716: 1068.693603515625, 13.0.
#   Channel 211, tick 717: 161.7237548828125, 0.0.
#   Channel 211, tick 718: 36.995201110839844, 0.0.
#   Channel 211, tick 719: 87.56587219238281, 0.0.
#   Channel 212, tick 711: 23.78904914855957, 0.0.
#   Channel 212, tick 712: 144.26170349121094, 0.0.
#   Channel 212, tick 713: 766.0977172851562, 13.0.
#   Channel 212, tick 714: 3496.927734375, 13.0.
#   Channel 212, tick 715: 3610.147705078125, 13.0.
#   Channel 212, tick 716: 1055.27783203125, 0.0.
#   Channel 212, tick 717: 286.2398376464844, 0.0.
#   Channel 212, tick 718: 22.342025756835938, 0.0.
#   Channel 212, tick 719: 30.6833553314209, 0.0.
#   Channel 213, tick 710: 135.29380798339844, 0.0.
#   Channel 213, tick 711: 127.98200988769531, 0.0.
#   Channel 213, tick 712: 55.31300735473633, 0.0.
#   Channel 213, tick 713: 1014.21923828125, 13.0.
#   Channel 213, tick 714: 4231.45654296875, 13.0.
#   Channel 213, tick 715: 4208.140625, 13.0.
#   Channel 213, tick 716: 1012.0388793945312, 13.0.
#   Channel 213, tick 717: 204.853271484375, 0.0.
#   Channel 213, tick 718: 107.95014953613281, 0.0.
#   Channel 214, tick 710: 48.515869140625, 0.0.
#   Channel 214, tick 711: 1.5654298067092896, 0.0.
#   Channel 214, tick 713: 799.567626953125, 13.0.
#   Channel 214, tick 714: 3749.2294921875, 13.0.
#   Channel 214, tick 715: 3586.60009765625, 13.0.
#   Channel 214, tick 716: 629.3931274414062, 13.0.
#   Channel 214, tick 717: 201.0606689453125, 0.0.
#   Channel 214, tick 718: 114.70120239257812, 0.0.
#   Channel 214, tick 719: 3.526702880859375, 0.0.
#   Channel 215, tick 705: 26.07171630859375, 0.0.
#   Channel 215, tick 706: 0.2176513671875, 0.0.
#   Channel 215, tick 713: 479.1316223144531, 13.0.
#   Channel 215, tick 714: 2693.73779296875, 13.0.
#   Channel 215, tick 715: 2011.7044677734375, 13.0.
#   Channel 215, tick 716: 158.10140991210938, 0.0.
#   Channel 216, tick 705: 147.15919494628906, 13.0.
#   Channel 216, tick 706: 991.5348510742188, 13.0.
#   Channel 216, tick 707: 784.2871704101562, 13.0.
#   Channel 216, tick 708: 184.44361877441406, 0.0.
#   Channel 216, tick 709: 9.75704574584961, 0.0.
#   Channel 216, tick 710: 36.16508483886719, 0.0.
#   Channel 216, tick 711: 10.45438003540039, 0.0.
#   Channel 216, tick 712: 134.7494659423828, 0.0.
#   Channel 216, tick 713: 832.798583984375, 13.0.
#   Channel 216, tick 714: 2945.8720703125, 13.0.
#   Channel 216, tick 715: 1739.3233642578125, 13.0.
#   Channel 216, tick 716: 179.97775268554688, 0.0.
#   Channel 216, tick 717: 18.291988372802734, 0.0.
#   Channel 217, tick 702: 6.067054748535156, 0.0.
#   Channel 217, tick 705: 967.0657348632812, 13.0.
#   Channel 217, tick 706: 3756.7763671875, 13.0.
#   Channel 217, tick 707: 2474.03369140625, 13.0.
#   Channel 217, tick 708: 219.05322265625, 0.0.
#   Channel 217, tick 712: 39.20099639892578, 0.0.
#   Channel 217, tick 713: 1042.3819580078125, 13.0.
#   Channel 217, tick 714: 3271.029541015625, 13.0.
#   Channel 217, tick 715: 1706.0059814453125, 13.0.
#   Channel 217, tick 716: 168.5970916748047, 0.0.
#   Channel 217, tick 717: 159.10198974609375, 0.0.
#   Channel 217, tick 718: 28.48863410949707, 0.0.
#   Channel 218, tick 702: 1.9383164644241333, 0.0.
#   Channel 218, tick 704: 56.505550384521484, 13.0.
#   Channel 218, tick 705: 2077.71728515625, 13.0.
#   Channel 218, tick 706: 5484.3076171875, 13.0.
#   Channel 218, tick 707: 2952.733642578125, 13.0.
#   Channel 218, tick 708: 230.6482696533203, 0.0.
#   Channel 218, tick 712: 196.583984375, 0.0.
#   Channel 218, tick 713: 1783.91455078125, 13.0.
#   Channel 218, tick 714: 3962.980712890625, 13.0.
#   Channel 218, tick 715: 1849.551513671875, 13.0.
#   Channel 218, tick 716: 159.00917053222656, 0.0.
#   Channel 218, tick 717: 78.59123229980469, 0.0.
#   Channel 218, tick 718: 88.41231536865234, 0.0.
#   Channel 218, tick 719: 0.11765766143798828, 0.0.
#   Channel 219, tick 704: 377.42340087890625, 13.0.
#   Channel 219, tick 705: 3203.936767578125, 13.0.
#   Channel 219, tick 706: 5430.0791015625, 13.0.
#   Channel 219, tick 707: 2283.095703125, 13.0.
#   Channel 219, tick 708: 113.96401977539062, 13.0.
#   Channel 219, tick 712: 17.559463500976562, 0.0.
#   Channel 219, tick 713: 1717.288330078125, 13.0.
#   Channel 219, tick 714: 4041.5751953125, 13.0.
#   Channel 219, tick 715: 1568.525146484375, 13.0.
#   Channel 219, tick 716: 44.97135925292969, 0.0.
#   Channel 219, tick 719: 0.728424072265625, 0.0.
#   Channel 220, tick 703: 26.813081741333008, 0.0.
#   Channel 220, tick 704: 1254.847412109375, 13.0.
#   Channel 220, tick 705: 3871.9716796875, 13.0.
#   Channel 220, tick 706: 4421.87939453125, 13.0.
#   Channel 220, tick 707: 1546.845947265625, 13.0.
#   Channel 220, tick 708: 96.1357421875, 13.0.
#   Channel 220, tick 712: 120.41192626953125, 0.0.
#   Channel 220, tick 713: 1806.480224609375, 13.0.
#   Channel 220, tick 714: 3633.26904296875, 13.0.
#   Channel 220, tick 715: 1363.87158203125, 13.0.
#   Channel 220, tick 716: 188.67648315429688, 0.0.
#   Channel 220, tick 717: 11.272430419921875, 0.0.
#   Channel 220, tick 718: 29.05682373046875, 0.0.
#   Channel 221, tick 702: 21.029937744140625, 0.0.
#   Channel 221, tick 703: 447.58209228515625, 13.0.
#   Channel 221, tick 704: 2227.5908203125, 13.0.
#   Channel 221, tick 705: 4129.8720703125, 13.0.
#   Channel 221, tick 706: 3836.055908203125, 13.0.
#   Channel 221, tick 707: 1514.70703125, 13.0.
#   Channel 221, tick 708: 237.63388061523438, 0.0.
#   Channel 221, tick 709: 258.002685546875, 0.0.
#   Channel 221, tick 710: 126.57589721679688, 0.0.
#   Channel 221, tick 711: 29.90924072265625, 0.0.
#   Channel 221, tick 712: 547.0802612304688, 13.0.
#   Channel 221, tick 713: 2059.424560546875, 13.0.
#   Channel 221, tick 714: 3238.95654296875, 13.0.
#   Channel 221, tick 715: 1185.6767578125, 13.0.
#   Channel 221, tick 716: 251.29925537109375, 0.0.
#   Channel 221, tick 717: 114.76071166992188, 0.0.
#   Channel 221, tick 718: 202.84506225585938, 0.0.
#   Channel 221, tick 719: 14.050750732421875, 0.0.
#   Channel 222, tick 700: 63.68170928955078, 0.0.
#   Channel 222, tick 702: 5.424034118652344, 0.0.
#   Channel 222, tick 703: 511.7826232910156, 13.0.
#   Channel 222, tick 704: 2732.888427734375, 13.0.
#   Channel 222, tick 705: 4309.75732421875, 13.0.
#   Channel 222, tick 706: 3656.9755859375, 13.0.
#   Channel 222, tick 707: 1515.9735107421875, 13.0.
#   Channel 222, tick 708: 206.56942749023438, 0.0.
#   Channel 222, tick 709: 8.490859985351562, 0.0.
#   Channel 222, tick 710: 12.564178466796875, 0.0.
#   Channel 222, tick 711: 66.27180480957031, 13.0.
#   Channel 222, tick 712: 636.3432006835938, 13.0.
#   Channel 222, tick 713: 2217.817626953125, 13.0.
#   Channel 222, tick 714: 2773.40771484375, 13.0.
#   Channel 222, tick 715: 766.7574462890625, 13.0.
#   Channel 222, tick 716: 87.42706298828125, 0.0.
#   Channel 222, tick 717: 12.867813110351562, 0.0.
#   Channel 222, tick 718: 8.276611328125, 0.0.
#   Channel 223, tick 700: 42.82438659667969, 0.0.
#   Channel 223, tick 701: 136.0542755126953, 0.0.
#   Channel 223, tick 702: 441.96380615234375, 0.0.
#   Channel 223, tick 703: 1138.3052978515625, 13.0.
#   Channel 223, tick 704: 4372.4150390625, 13.0.
#   Channel 223, tick 705: 5497.3671875, 13.0.
#   Channel 223, tick 706: 3341.22998046875, 13.0.
#   Channel 223, tick 707: 1052.2181396484375, 13.0.
#   Channel 223, tick 708: 185.76727294921875, 0.0.
#   Channel 223, tick 709: 164.05262756347656, 0.0.
#   Channel 223, tick 710: 343.71124267578125, 0.0.
#   Channel 223, tick 711: 380.0574035644531, 13.0.
#   Channel 223, tick 712: 838.744140625, 13.0.
#   Channel 223, tick 713: 2849.3740234375, 13.0.
#   Channel 223, tick 714: 2776.530029296875, 13.0.
#   Channel 223, tick 715: 733.1829223632812, 13.0.
#   Channel 223, tick 716: 146.48643493652344, 0.0.
#   Channel 223, tick 717: 216.10513305664062, 0.0.
#   Channel 223, tick 718: 147.74012756347656, 0.0.
#   Channel 223, tick 719: 1.935821533203125, 0.0.
#   Channel 224, tick 697: 17.430187225341797, 0.0.
#   Channel 224, tick 698: 12.030176162719727, 0.0.
#   Channel 224, tick 699: 307.4487609863281, 13.0.
#   Channel 224, tick 700: 1007.2135009765625, 13.0.
#   Channel 224, tick 701: 1090.13427734375, 13.0.
#   Channel 224, tick 702: 1107.597412109375, 13.0.
#   Channel 224, tick 703: 2523.0, 13.0.
#   Channel 224, tick 704: 6081.39111328125, 13.0.
#   Channel 224, tick 705: 5592.64697265625, 13.0.
#   Channel 224, tick 706: 1508.2081298828125, 13.0.
#   Channel 224, tick 707: 49.567466735839844, 0.0.
#   Channel 224, tick 709: 122.65090942382812, 0.0.
#   Channel 224, tick 710: 260.0582275390625, 0.0.
#   Channel 224, tick 711: 236.13131713867188, 13.0.
#   Channel 224, tick 712: 606.2574462890625, 13.0.
#   Channel 224, tick 713: 2776.503173828125, 13.0.
#   Channel 224, tick 714: 2788.084228515625, 13.0.
#   Channel 224, tick 715: 619.0408935546875, 0.0.
#   Channel 224, tick 717: 23.904766082763672, 0.0.
#   Channel 224, tick 718: 214.6175537109375, 0.0.
#   Channel 224, tick 719: 23.803424835205078, 0.0.
# ...
#   Channel 2011, tick 694: 49.25, 0.0.
#   Channel 2012, tick 688: 35.25, 0.0.
#   Channel 2012, tick 689: 21.5, 0.0.
#   Channel 2012, tick 690: 1055.0, 13.0.
#   Channel 2012, tick 691: 2977.0, 13.0.
#   Channel 2012, tick 692: 1596.75, 13.0.
#   Channel 2012, tick 693: 123.5, 0.0.
#   Channel 2013, tick 688: 52.0, 0.0.
#   Channel 2013, tick 689: 32.5, 0.0.
#   Channel 2013, tick 690: 1309.5, 13.0.
#   Channel 2013, tick 691: 3041.0, 13.0.
#   Channel 2013, tick 692: 1332.0, 13.0.
#   Channel 2013, tick 693: 147.5, 0.0.
#   Channel 2013, tick 694: 25.25, 0.0.
#   Channel 2014, tick 688: 87.5, 0.0.
#   Channel 2014, tick 689: 339.0, 13.0.
#   Channel 2014, tick 690: 2351.5, 13.0.
#   Channel 2014, tick 691: 4668.5, 13.0.
#   Channel 2014, tick 692: 1913.5, 13.0.
#   Channel 2014, tick 693: 172.0, 0.0.
#   Channel 2015, tick 688: 7.75, 0.0.
#   Channel 2015, tick 689: 268.25, 13.0.
#   Channel 2015, tick 690: 2030.75, 13.0.
#   Channel 2015, tick 691: 2956.25, 13.0.
#   Channel 2015, tick 692: 911.0, 13.0.
#   Channel 2015, tick 693: 77.5, 0.0.
#   Channel 2015, tick 694: 37.0, 0.0.
#   Channel 2016, tick 689: 377.75, 13.0.
#   Channel 2016, tick 690: 2158.5, 13.0.
#   Channel 2016, tick 691: 2572.75, 13.0.
#   Channel 2016, tick 692: 592.25, 13.0.
#   Channel 2016, tick 693: 63.25, 0.0.
#   Channel 2017, tick 688: 24.0, 0.0.
#   Channel 2017, tick 689: 546.0, 13.0.
#   Channel 2017, tick 690: 2680.25, 13.0.
#   Channel 2017, tick 691: 2516.25, 13.0.
#   Channel 2017, tick 692: 475.0, 0.0.
#   Channel 2018, tick 688: 91.25, 0.0.
#   Channel 2018, tick 689: 635.5, 13.0.
#   Channel 2018, tick 690: 2555.25, 13.0.
#   Channel 2018, tick 691: 2081.5, 13.0.
#   Channel 2018, tick 692: 318.0, 0.0.
#   Channel 2019, tick 688: 41.5, 0.0.
#   Channel 2019, tick 689: 842.25, 13.0.
#   Channel 2019, tick 690: 2602.5, 13.0.
#   Channel 2019, tick 691: 1665.25, 13.0.
#   Channel 2019, tick 692: 225.5, 0.0.
#   Channel 2019, tick 693: 3.75, 0.0.
#   Channel 2020, tick 687: 88.0, 0.0.
#   Channel 2020, tick 688: 158.25, 0.0.
#   Channel 2020, tick 689: 1078.75, 13.0.
#   Channel 2020, tick 690: 2840.75, 13.0.
#   Channel 2020, tick 691: 1513.0, 13.0.
#   Channel 2020, tick 692: 159.75, 13.0.
#   Channel 2020, tick 693: 58.75, 13.0.
#   Channel 2021, tick 687: 110.0, 0.0.
#   Channel 2021, tick 688: 251.75, 13.0.
#   Channel 2021, tick 689: 2257.75, 13.0.
#   Channel 2021, tick 690: 4295.5, 13.0.
#   Channel 2021, tick 691: 1821.0, 13.0.
#   Channel 2021, tick 692: 88.5, 13.0.
#   Channel 2022, tick 687: 107.75, 0.0.
#   Channel 2022, tick 688: 829.75, 13.0.
#   Channel 2022, tick 689: 4896.75, 13.0.
#   Channel 2022, tick 690: 7402.75, 13.0.
#   Channel 2022, tick 691: 2779.25, 13.0.
#   Channel 2022, tick 692: 197.0, 0.0.
#   Channel 2022, tick 693: 8.25, 0.0.
#   Channel 2023, tick 687: 4.75, 0.0.
#   Channel 2023, tick 688: 264.0, 13.0.
#   Channel 2023, tick 689: 2086.25, 13.0.
#   Channel 2023, tick 690: 3274.5, 13.0.
#   Channel 2023, tick 691: 975.0, 13.0.
#   Channel 2023, tick 692: 17.5, 0.0.
#   Channel 2023, tick 693: 8.5, 0.0.
#   Channel 2024, tick 687: 14.749999046325684, 0.0.
#   Channel 2024, tick 688: 405.0, 13.0.
#   Channel 2024, tick 689: 2164.25, 13.0.
#   Channel 2024, tick 690: 2613.0, 13.0.
#   Channel 2024, tick 691: 617.0, 13.0.
#   Channel 2024, tick 692: 48.25, 0.0.
#   Channel 2025, tick 687: 37.25, 0.0.
#   Channel 2025, tick 688: 570.5, 13.0.
#   Channel 2025, tick 689: 2562.75, 13.0.
#   Channel 2025, tick 690: 2443.75, 13.0.
#   Channel 2025, tick 691: 520.5, 0.0.
#   Channel 2025, tick 692: 102.25, 0.0.
#   Channel 2026, tick 687: 65.25, 0.0.
#   Channel 2026, tick 688: 994.5, 13.0.
#   Channel 2026, tick 689: 4016.5, 13.0.
#   Channel 2026, tick 690: 3255.75, 13.0.
#   Channel 2026, tick 691: 574.5, 0.0.
#   Channel 2026, tick 692: 60.25, 0.0.
#   Channel 2027, tick 687: 121.0, 0.0.
#   Channel 2027, tick 688: 1459.0, 13.0.
#   Channel 2027, tick 689: 4311.5, 13.0.
#   Channel 2027, tick 690: 2851.25, 13.0.
#   Channel 2027, tick 691: 345.25, 0.0.
#   Channel 2027, tick 692: 20.75, 0.0.
#   Channel 2028, tick 687: 38.75, 0.0.
#   Channel 2028, tick 688: 1225.75, 13.0.
#   Channel 2028, tick 689: 3081.0, 13.0.
#   Channel 2028, tick 690: 1667.0, 13.0.
#   Channel 2028, tick 691: 177.5, 0.0.
#   Channel 2028, tick 692: 5.5, 0.0.
#   Channel 2029, tick 686: 23.0, 0.0.
#   Channel 2029, tick 687: 97.75, 0.0.
#   Channel 2029, tick 688: 1223.25, 13.0.
#   Channel 2029, tick 689: 2555.75, 13.0.
#   Channel 2029, tick 690: 1186.25, 13.0.
#   Channel 2029, tick 691: 70.5, 0.0.
#   Channel 2030, tick 687: 215.5, 13.0.
#   Channel 2030, tick 688: 1897.25, 13.0.
#   Channel 2030, tick 689: 2993.25, 13.0.
#   Channel 2030, tick 690: 1007.5, 13.0.
#   Channel 2030, tick 691: 52.25, 0.0.
#   Channel 2031, tick 686: 77.75, 0.0.
#   Channel 2031, tick 687: 405.75, 13.0.
#   Channel 2031, tick 688: 2179.75, 13.0.
#   Channel 2031, tick 689: 2912.5, 13.0.
#   Channel 2031, tick 690: 855.5, 13.0.
#   Channel 2031, tick 691: 116.25, 0.0.
#   Channel 2032, tick 686: 29.75, 0.0.
#   Channel 2032, tick 687: 294.0, 13.0.
#   Channel 2032, tick 688: 2243.25, 13.0.
#   Channel 2032, tick 689: 2720.5, 13.0.
#   Channel 2032, tick 690: 654.75, 13.0.
#   Channel 2032, tick 691: 17.0, 0.0.
#   Channel 2033, tick 686: 111.25, 0.0.
#   Channel 2033, tick 687: 651.25, 13.0.
#   Channel 2033, tick 688: 2442.25, 13.0.
#   Channel 2033, tick 689: 2391.5, 13.0.
#   Channel 2033, tick 690: 500.0, 0.0.
#   Channel 2033, tick 691: 34.75, 0.0.
#   Channel 2034, tick 686: 58.75, 0.0.
#   Channel 2034, tick 687: 916.75, 13.0.
#   Channel 2034, tick 688: 2995.75, 13.0.
#   Channel 2034, tick 689: 2396.0, 13.0.
#   Channel 2034, tick 690: 388.25, 0.0.
#   Channel 2034, tick 691: 46.5, 0.0.
#   Channel 2035, tick 685: 9.5, 0.0.
#   Channel 2035, tick 686: 32.5, 0.0.
#   Channel 2035, tick 687: 939.25, 13.0.
#   Channel 2035, tick 688: 2976.75, 13.0.
#   Channel 2035, tick 689: 1941.25, 13.0.
#   Channel 2035, tick 690: 233.25, 0.0.
#   Channel 2036, tick 685: 33.75, 0.0.
#   Channel 2036, tick 686: 155.5, 0.0.
#   Channel 2036, tick 687: 1178.25, 13.0.
#   Channel 2036, tick 688: 2869.0, 13.0.
#   Channel 2036, tick 689: 1555.75, 13.0.
#   Channel 2036, tick 690: 218.5, 0.0.
#   Channel 2036, tick 691: 2.75, 0.0.
#   Channel 2037, tick 685: 13.5, 0.0.
#   Channel 2037, tick 686: 128.5, 0.0.
#   Channel 2037, tick 687: 1483.0, 13.0.
#   Channel 2037, tick 688: 3037.0, 13.0.
#   Channel 2037, tick 689: 1374.5, 13.0.
#   Channel 2037, tick 690: 132.25, 0.0.
#   Channel 2038, tick 686: 253.5, 13.0.
#   Channel 2038, tick 687: 2606.5, 13.0.
#   Channel 2038, tick 688: 4570.5, 13.0.
#   Channel 2038, tick 689: 1654.5, 13.0.
#   Channel 2038, tick 690: 122.75, 0.0.
#   Channel 2039, tick 686: 472.0, 13.0.
#   Channel 2039, tick 687: 3484.0, 13.0.
#   Channel 2039, tick 688: 5152.5, 13.0.
#   Channel 2039, tick 689: 1560.5, 13.0.
#   Channel 2039, tick 690: 99.0, 0.0.
#   Channel 2040, tick 685: 19.25, 0.0.
#   Channel 2040, tick 686: 576.75, 13.0.
#   Channel 2040, tick 687: 2351.75, 13.0.
#   Channel 2040, tick 688: 2622.0, 13.0.
#   Channel 2040, tick 689: 674.25, 13.0.
#   Channel 2040, tick 690: 96.25, 0.0.
#   Channel 2041, tick 686: 518.75, 13.0.
#   Channel 2041, tick 687: 2650.0, 13.0.
#   Channel 2041, tick 688: 2532.75, 13.0.
#   Channel 2041, tick 689: 407.5, 0.0.
#   Channel 2041, tick 690: 1.0, 0.0.
#   Channel 2042, tick 685: 23.0, 0.0.
#   Channel 2042, tick 686: 810.25, 13.0.
#   Channel 2042, tick 687: 2821.25, 13.0.
#   Channel 2042, tick 688: 2100.75, 13.0.
#   Channel 2042, tick 689: 299.25, 0.0.
#   Channel 2042, tick 690: 54.75, 0.0.
#   Channel 2043, tick 685: 14.0, 0.0.
#   Channel 2043, tick 686: 893.5, 13.0.
#   Channel 2043, tick 687: 2976.25, 13.0.
#   Channel 2043, tick 688: 1852.75, 13.0.
#   Channel 2043, tick 689: 267.25, 0.0.
#   Channel 2043, tick 690: 38.75, 0.0.
#   Channel 2044, tick 684: 12.25, 0.0.
#   Channel 2044, tick 685: 49.5, 0.0.
#   Channel 2044, tick 686: 1396.5, 13.0.
#   Channel 2044, tick 687: 3601.75, 13.0.
#   Channel 2044, tick 688: 1825.5, 13.0.
#   Channel 2044, tick 689: 263.75, 0.0.
#   Channel 2044, tick 690: 17.25, 0.0.
#   Channel 2045, tick 684: 13.5, 0.0.
#   Channel 2045, tick 685: 210.0, 0.0.
#   Channel 2045, tick 686: 2438.25, 13.0.
#   Channel 2045, tick 687: 6607.0, 13.0.
#   Channel 2045, tick 688: 4231.25, 13.0.
#   Channel 2045, tick 689: 693.75, 13.0.
#   Channel 2045, tick 690: 13.75, 0.0.
#   Channel 2046, tick 684: 71.0, 0.0.
#   Channel 2046, tick 685: 266.5, 13.0.
#   Channel 2046, tick 686: 3295.5, 13.0.
#   Channel 2046, tick 687: 6997.5, 13.0.
#   Channel 2046, tick 688: 3709.25, 13.0.
#   Channel 2046, tick 689: 567.0, 13.0.
#   Channel 2046, tick 690: 25.5, 0.0.
#   Channel 2047, tick 684: 1.0, 0.0.
#   Channel 2047, tick 685: 326.25, 13.0.
#   Channel 2047, tick 686: 2928.0, 13.0.
#   Channel 2047, tick 687: 4466.75, 13.0.
#   Channel 2047, tick 688: 1459.25, 13.0.
#   Channel 2047, tick 689: 241.5, 0.0.
#   Channel 2048, tick 684: 13.75, 0.0.
#   Channel 2048, tick 685: 235.0, 13.0.
#   Channel 2048, tick 686: 2267.25, 13.0.
#   Channel 2048, tick 687: 2825.75, 13.0.
#   Channel 2048, tick 688: 613.5, 13.0.
#   Channel 2048, tick 689: 59.25, 0.0.
#   Channel 2048, tick 690: 9.5, 0.0.
#   Channel 2049, tick 684: 42.25, 0.0.
#   Channel 2049, tick 685: 608.25, 13.0.
#   Channel 2049, tick 686: 2691.75, 13.0.
#   Channel 2049, tick 687: 2733.75, 13.0.
#   Channel 2049, tick 688: 619.0, 0.0.
#   Channel 2049, tick 689: 59.0, 0.0.
#   Channel 2050, tick 685: 636.0, 13.0.
#   Channel 2050, tick 686: 2623.5, 13.0.
#   Channel 2050, tick 687: 2115.25, 13.0.
#   Channel 2050, tick 688: 329.25, 0.0.
#   Channel 2050, tick 689: 4.0, 0.0.
#   Channel 2051, tick 684: 104.25, 13.0.
#   Channel 2051, tick 685: 1713.75, 13.0.
#   Channel 2051, tick 686: 4264.5, 13.0.
#   Channel 2051, tick 687: 2535.0, 13.0.
#   Channel 2051, tick 688: 237.5, 0.0.
#   Channel 2052, tick 684: 124.25, 13.0.
#   Channel 2052, tick 685: 2354.5, 13.0.
#   Channel 2052, tick 686: 5318.75, 13.0.
#   Channel 2052, tick 687: 2718.25, 13.0.
#   Channel 2052, tick 688: 284.0, 0.0.
#   Channel 2052, tick 689: 4.0, 0.0.
#   Channel 2053, tick 683: 34.25, 0.0.
#   Channel 2053, tick 684: 134.25, 0.0.
#   Channel 2053, tick 685: 1594.5, 13.0.
#   Channel 2053, tick 686: 3602.75, 13.0.
#   Channel 2053, tick 687: 1524.5, 13.0.
#   Channel 2053, tick 688: 110.75, 0.0.
#   Channel 2053, tick 689: 94.0, 0.0.
#   Channel 2054, tick 683: 36.0, 0.0.
#   Channel 2054, tick 684: 133.5, 13.0.
#   Channel 2054, tick 685: 1531.75, 13.0.
#   Channel 2054, tick 686: 2702.75, 13.0.
#   Channel 2054, tick 687: 950.75, 13.0.
#   Channel 2054, tick 688: 189.0, 0.0.
#   Channel 2054, tick 689: 19.5, 0.0.
#   Channel 2055, tick 683: 7.75, 0.0.
#   Channel 2055, tick 684: 251.0, 13.0.
#   Channel 2055, tick 685: 2262.5, 13.0.
#   Channel 2055, tick 686: 3375.25, 13.0.
#   Channel 2055, tick 687: 937.75, 13.0.
#   Channel 2055, tick 688: 95.75, 0.0.
#   Channel 2056, tick 683: 13.0, 0.0.
#   Channel 2056, tick 684: 323.25, 13.0.
#   Channel 2056, tick 685: 2543.5, 13.0.
#   Channel 2056, tick 686: 3156.25, 13.0.
#   Channel 2056, tick 687: 773.75, 13.0.
#   Channel 2056, tick 688: 42.5, 0.0.
#   Channel 2057, tick 683: 16.25, 0.0.
#   Channel 2057, tick 684: 615.5, 13.0.
#   Channel 2057, tick 685: 2935.25, 13.0.
#   Channel 2057, tick 686: 2911.75, 13.0.
#   Channel 2057, tick 687: 562.0, 0.0.
#   Channel 2057, tick 688: 36.25, 0.0.
#   Channel 2058, tick 683: 30.5, 0.0.
#   Channel 2058, tick 684: 845.25, 13.0.
#   Channel 2058, tick 685: 3186.25, 13.0.
#   Channel 2058, tick 686: 2806.75, 13.0.
#   Channel 2058, tick 687: 476.5, 0.0.
#   Channel 2058, tick 688: 28.25, 0.0.
#   Channel 2059, tick 683: 27.75, 0.0.
#   Channel 2059, tick 684: 824.5, 13.0.
#   Channel 2059, tick 685: 2901.0, 13.0.
#   Channel 2059, tick 686: 2062.5, 13.0.
#   Channel 2059, tick 687: 314.0, 0.0.
#   Channel 2059, tick 688: 33.75, 0.0.
#   Channel 2060, tick 683: 42.0, 0.0.
#   Channel 2060, tick 684: 1093.75, 13.0.
#   Channel 2060, tick 685: 2909.5, 13.0.
#   Channel 2060, tick 686: 1789.75, 13.0.
#   Channel 2060, tick 687: 303.25, 0.0.
#   Channel 2060, tick 688: 8.75, 0.0.
#   Channel 2061, tick 682: 6.5, 0.0.
#   Channel 2061, tick 683: 44.75, 0.0.
#   Channel 2061, tick 684: 1260.75, 13.0.
#   Channel 2061, tick 685: 3017.5, 13.0.
#   Channel 2061, tick 686: 1399.0, 13.0.
#   Channel 2061, tick 687: 121.75, 0.0.
#   Channel 2062, tick 683: 73.5, 0.0.
#   Channel 2062, tick 684: 1726.25, 13.0.
#   Channel 2062, tick 685: 3270.75, 13.0.
#   Channel 2062, tick 686: 1122.75, 13.0.
#   Channel 2062, tick 687: 86.75, 0.0.
#   Channel 2062, tick 688: 2.75, 0.0.
#   Channel 2063, tick 683: 213.25, 13.0.
#   Channel 2063, tick 684: 2091.0, 13.0.
#   Channel 2063, tick 685: 3279.0, 13.0.
#   Channel 2063, tick 686: 1006.25, 13.0.
#   Channel 2063, tick 687: 52.25, 0.0.
#   Channel 2064, tick 683: 309.25, 13.0.
#   Channel 2064, tick 684: 2044.25, 13.0.
#   Channel 2064, tick 685: 2634.5, 13.0.
#   Channel 2064, tick 686: 699.0, 13.0.
#   Channel 2064, tick 687: 144.25, 0.0.
#   Channel 2065, tick 683: 393.7499694824219, 13.0.
#   Channel 2065, tick 684: 2517.75, 13.0.
#   Channel 2065, tick 685: 2743.25, 13.0.
#   Channel 2065, tick 686: 713.0, 0.0.
#   Channel 2065, tick 687: 53.5, 0.0.
#   Channel 2066, tick 682: 26.25, 0.0.
#   Channel 2066, tick 683: 569.5, 13.0.
#   Channel 2066, tick 684: 2326.25, 13.0.
#   Channel 2066, tick 685: 2230.75, 13.0.
#   Channel 2066, tick 686: 376.75, 0.0.
#   Channel 2067, tick 682: 76.5, 0.0.
#   Channel 2067, tick 683: 819.75, 13.0.
#   Channel 2067, tick 684: 3166.5, 13.0.
#   Channel 2067, tick 685: 2612.75, 13.0.
#   Channel 2067, tick 686: 465.0, 0.0.
#   Channel 2068, tick 682: 101.75, 0.0.
#   Channel 2068, tick 683: 1094.0, 13.0.
#   Channel 2068, tick 684: 3745.0, 13.0.
#   Channel 2068, tick 685: 2541.5, 13.0.
#   Channel 2068, tick 686: 252.25, 0.0.
#   Channel 2069, tick 682: 95.50000762939453, 0.0.
#   Channel 2069, tick 683: 1121.5, 13.0.
#   Channel 2069, tick 684: 3155.25, 13.0.
#   Channel 2069, tick 685: 1835.0, 13.0.
#   Channel 2069, tick 686: 209.5, 0.0.
#   Channel 2069, tick 687: 2.0, 0.0.
#   Channel 2070, tick 681: 36.0, 0.0.
#   Channel 2070, tick 682: 196.5, 0.0.
#   Channel 2070, tick 683: 1346.25, 13.0.
#   Channel 2070, tick 684: 3178.0, 13.0.
#   Channel 2070, tick 685: 1595.75, 13.0.
#   Channel 2070, tick 686: 271.5, 0.0.
#   Channel 2070, tick 687: 9.0, 0.0.
#   Channel 2071, tick 681: 17.5, 0.0.
#   Channel 2071, tick 682: 355.0, 0.0.
#   Channel 2071, tick 683: 1615.25, 13.0.
#   Channel 2071, tick 684: 2971.75, 13.0.
#   Channel 2071, tick 685: 1162.75, 13.0.
#   Channel 2071, tick 686: 58.0, 0.0.
#   Channel 2072, tick 681: 30.5, 0.0.
#   Channel 2072, tick 682: 406.0, 13.0.
#   Channel 2072, tick 683: 2144.0, 13.0.
#   Channel 2072, tick 684: 3374.75, 13.0.
#   Channel 2072, tick 685: 1045.75, 13.0.
#   Channel 2072, tick 686: 64.25, 0.0.
#   Channel 2073, tick 681: 1.75, 0.0.
#   Channel 2073, tick 682: 411.25, 13.0.
#   Channel 2073, tick 683: 2329.25, 13.0.
#   Channel 2073, tick 684: 3018.25, 13.0.
#   Channel 2073, tick 685: 659.0, 13.0.
#   Channel 2073, tick 686: 109.25, 0.0.
#   Channel 2074, tick 681: 18.25, 0.0.
#   Channel 2074, tick 682: 656.5, 13.0.
#   Channel 2074, tick 683: 2871.0, 13.0.
#   Channel 2074, tick 684: 2943.75, 13.0.
#   Channel 2074, tick 685: 642.5, 0.0.
#   Channel 2074, tick 686: 64.0, 0.0.
#   Channel 2075, tick 681: 33.5, 0.0.
#   Channel 2075, tick 682: 620.75, 13.0.
#   Channel 2075, tick 683: 2789.0, 13.0.
#   Channel 2075, tick 684: 2711.25, 13.0.
#   Channel 2075, tick 685: 444.5, 0.0.
#   Channel 2076, tick 681: 14.0, 0.0.
#   Channel 2076, tick 682: 786.5, 13.0.
#   Channel 2076, tick 683: 2843.5, 13.0.
#   Channel 2076, tick 684: 2161.75, 13.0.
#   Channel 2076, tick 685: 304.5, 0.0.
#   Channel 2076, tick 686: 2.5, 0.0.
#   Channel 2077, tick 681: 66.0, 0.0.
#   Channel 2077, tick 682: 1159.25, 13.0.
#   Channel 2077, tick 683: 3375.0, 13.0.
#   Channel 2077, tick 684: 2179.5, 13.0.
#   Channel 2077, tick 685: 197.75, 0.0.
#   Channel 2077, tick 686: 7.0, 0.0.
#   Channel 2078, tick 680: 70.75, 0.0.
#   Channel 2078, tick 681: 249.25, 0.0.
#   Channel 2078, tick 682: 1100.0, 13.0.
#   Channel 2078, tick 683: 3059.5, 13.0.
#   Channel 2078, tick 684: 1664.25, 13.0.
#   Channel 2078, tick 685: 123.0, 0.0.
#   Channel 2078, tick 686: 5.25, 0.0.
#   Channel 2079, tick 680: 33.0, 0.0.
#   Channel 2079, tick 681: 257.25, 0.0.
#   Channel 2079, tick 682: 1715.0, 13.0.
#   Channel 2079, tick 683: 3712.5, 13.0.
#   Channel 2079, tick 684: 1566.75, 13.0.
#   Channel 2079, tick 685: 43.25, 0.0.

# %% [markdown]
# ## Compare reading from pickle vs HDF5: both sparse!

# %%
ptpath = "../../apa-test-data/pickle/out_monte-carlo-011984-000100_279569_164_1_20260116T164131Z/" \
        "monte-carlo-011984-000100_279569_164_1_20260116T164131Z_g4-tru-anode0_sparse.pt"

h5path = "../../apa-test-data/sparse_gzip2/out_monte-carlo-011984-000100_279569_164_1_20260116T164131Z/" \
        "monte-carlo-011984-000100_279569_164_1_20260116T164131Z_g4-tru-anode0.h5"

# %%
sparse_groups = torch.load(ptpath, map_location="cpu",weights_only=False)
voxels_per_group = {}

for group, data in sparse_groups.items():
    coords   = data["coords"]
    feats    = data["features"]
    offsets  = data["offsets"]

    coords_b = IntCoords(coords, offsets=offsets)
    feats_b  = CatFeatures(feats, offsets=offsets)

    vox = Voxels(
        batched_coordinates=coords_b,
        batched_features=feats_b,
        offsets=offsets
    )

    voxels_per_group[group] = vox

    if group == "1":
        debug_print_voxels(vox, prefix=f"[PT reconstructed {group}] ")
# Out:
# [PT reconstructed 1] Voxels summary
# Type: <class 'warpconvnet.geometry.types.voxels.Voxels'>
# Batch size: 1
# Num spatial dims: 2
# Num channels: 1
# Num active voxels: 7480
# Core tensors:
#   coordinate_tensor: torch.Size([7480, 2]) torch.int32 cpu
#   feature_tensor: torch.Size([7480, 1]) torch.float32 cpu
#   offsets: torch.Size([2]) torch.int64 cpu

# %%
h5_path = Path(h5path)

with h5py.File(h5_path, "r") as f:

    for group in f.keys():
   
        coords = f[group][FRAME_RECO]["coords"][()]  # (channels, ticks)
        features = f[group][FRAME_RECO]["features"][()]
        offsets = np.array([0,features.shape[0]])

        N = features.shape[0]
        offsets = np.array([0, N], dtype=np.int32)

        coords_torch = torch.from_numpy(coords).to(torch.int32)
        features_torch = (torch.from_numpy(features).to(torch.float32).unsqueeze(1))
        offsets_torch = torch.from_numpy(offsets)

        coords_b = IntCoords(coords_torch, offsets=offsets_torch)
        feats_b  = CatFeatures(features_torch, offsets=offsets_torch)

        vox = Voxels(
            batched_coordinates=coords_b,
            batched_features=feats_b,
            offsets=offsets_torch,
        )

        if group == "1":
            debug_print_voxels(vox, prefix=f"[H5 reconstructed {group}] ")
# Out:
# [H5 reconstructed 1] Voxels summary
# Type: <class 'warpconvnet.geometry.types.voxels.Voxels'>
# Batch size: 1
# Num spatial dims: 2
# Num channels: 1
# Num active voxels: 7480
# Core tensors:
#   coordinate_tensor: torch.Size([7480, 2]) torch.int32 cpu
#   feature_tensor: torch.Size([7480, 1]) torch.float32 cpu
#   offsets: torch.Size([2]) torch.int32 cpu
